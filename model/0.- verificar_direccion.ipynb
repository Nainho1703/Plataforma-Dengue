# %%
import sqlite3
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderUnavailable
import time
import difflib
import overpy
import warnings
import numpy as np
import unicodedata

warnings.filterwarnings("ignore")


def esta_en_villa_maria(lat, lon):
    return (-33 <= lat <= -29) and (-65 <= lon <= -63)

geolocator = Nominatim(user_agent="vm_dengue_mapper", timeout=20)
# Función con backoff progresivo y control de errores
def geocode_direccion(direccion, max_retries=5):
    delay = 2
    for intento in range(1, max_retries + 1):
        try:
            # print(f"[BUSCANDO] {direccion} (intento {intento})")
            time.sleep(delay)
            return geolocator.geocode(direccion)
        except (GeocoderTimedOut, GeocoderUnavailable) as e:
            print(f"[REINTENTO] {direccion} → {str(e)}")
            time.sleep(delay)
            delay *= 2  # Exponencial: 2, 4, 8...
        except Exception as e:
            print(f"[FALLO FATAL] {direccion} → {str(e)}")
            break
    return None



# — Obtención de la lista de calles con Overpass —
api = overpy.Overpass()
query = """
area["boundary"="administrative"]["name"="Villa María"]["admin_level"="8"]->.searchArea;
way["highway"]["name"](area.searchArea);
out;
"""
result = api.query(query)
calles = sorted({ way.tags["name"] for way in result.ways if "name" in way.tags })
import unicodedata
def normalize(texto: str) -> str:
    """
    Quita acentos y otros diacríticos, pero preserva la ñ, y convierte a mayúsculas.
    """
    # 1. Descomponer en NFKD (“ñ” para ñ, “á” para á, etc.)
    nfkd = unicodedata.normalize('NFKD', texto)
    out_chars = []
    prev = None

    for c in nfkd:
        if unicodedata.combining(c):
            # Sólo dejamos la tilde (~) si va sobre una 'n' o 'N'
            if c == '\u0303' and prev and prev.lower() == 'n':
                out_chars.append(c)
            # resto de diacríticos los descartamos
        else:
            out_chars.append(c)
            prev = c

    # 2. Unir, pasar a mayúsculas y recomponer (NFC) para que 'N'+~ vuelva a ser 'Ñ'
    result = ''.join(out_chars).upper()
    return unicodedata.normalize('NFC', result)

def buscar_calle_similar(texto, lista_calles, n=5, cutoff=0.6):
    # Normalizamos lista de calles
    originales = lista_calles
    normalized_calles = [normalize(c) for c in originales]
    target = normalize(texto)
    # Buscamos coincidencias en la forma normalizada
    matches = difflib.get_close_matches(target, normalized_calles, n=n, cutoff=cutoff)
    # Reconstruimos los nombres con acento original
    return [ originales[normalized_calles.index(m)] for m in matches ]

def procesar_coordenadas(df, lon_col='lon', lat_col='lat', wkt_col='WKT'):
    # 1. Detectar filas donde 'lon' contiene dos valores separados por coma
    mask = df[lon_col].astype(str).str.contains(',', na=False)

    # 2. Si no hay ninguna fila con coma, devolvemos el df sin cambios
    if not mask.any():
        return df

    # 3. Split y renombrado de columnas temporales

    
    split = (
        df.loc[mask, lon_col]
          .astype(str)
          .str.split(',', expand=True)
          .rename(columns={0: lat_col, 1: lon_col})
    )

    # 4. Limpiar espacios y convertir a float
    split[lat_col] = split[lat_col].str.replace('"','').str.strip().astype(float)
    split[lon_col] = split[lon_col].str.replace('"','').str.strip().astype(float)

    # 5. Asignar de vuelta al df original
    df.loc[mask, lat_col] = split[lat_col]
    df.loc[mask, lon_col] = split[lon_col]

    # 6. Generar la columna WKT
    df[wkt_col] = df.apply(
        lambda row: f"POINT({row[lon_col]} {row[lat_col]})"
                    if pd.notna(row[lon_col]) and pd.notna(row[lat_col])
                    else pd.NA,
        axis=1
    )

    return df
def geocode_intersection_op(street1, street2, area_name="Villa María"):
    query = f"""
    area["boundary"="administrative"]["name"="{area_name}"]->.a;
    way(area.a)["highway"]["name"="{street1}"]->.w1;
    way(area.a)["highway"]["name"="{street2}"]->.w2;
    node(w1.w2)->.n;
    out body n 1;
    """
    try:
        res = api.query(query)
        if res.nodes:
            n = res.nodes[0]
            return float(n.lat), float(n.lon)
    except Exception:
        pass
    return None
def is_intersection(addr):
    a = addr.lower()
    return " y " in a or " esq. " in a or " esq " in a

def split_intersection(addr):
    low = addr.lower()
    if " y " in low:
        parts = low.split(" y ", 1)
    elif " esq. " in low:
        parts = low.split(" esq. ", 1)
    else:
        parts = low.split(" esq ", 1)
    print(parts)
    return parts[0].strip().capitalize(), parts[1].strip().capitalize()

import numpy as np
import re


def asignar_location(location,df,idx,dir_raw,mensaje=0):
    lat = location.latitude
    lon = location.longitude
    
    if not esta_en_villa_maria(lat, lon):
        print(f"[ERROR GEO] Coordenadas fuera de Villa María: {dir_raw} → Lat: {lat}, Lon: {lon}")


    wkt = f"POINT({lon} {lat})"
    df.at[idx, 'lat'] = lat
    df.at[idx, 'lon'] = lon
    df.at[idx, 'WKT'] = wkt
    if mensaje==1:
        print(f"[ENCONTRADA] Dirección 2: {dir_raw} → Lat: {lat}, Lon: {lon}")
    else:
        print(f"[ENCONTRADA] Dirección: {dir_raw} → Lat: {lat}, Lon: {lon}")
    return df
def evaluar_direccion(df,columna_direccion="DIRECCION"):
    
    # Inicializar geocoder
   
    if "lon" not in df.columns:
        df["lon"]=np.nan
    # Filas con lon vacía
    faltantes = df[df['lon'].isna()].copy()

    # Si no hay una columna de dirección clara, asumimos una posible:

    contador=0

    reemplazos={'TTE.':'TENIENTE','INT':'INTENDENTE',"MEJICO":"MEXICO",'Antonio Hosch':'Enrique Antonio Hoch','Enrique A. Hoch':'Enrique Antonio Hoch',
                'T. PEÑA':"INTENDENTE PEÑA","EEUU":"ESTADOS UNIDOS",'BV ALVEAR':'Boulevard Marcelo T. de Alvear','CTDA. ': ""}
    for idx, row in faltantes.iterrows():
        contador += 1
        dir_raw = row[columna_direccion]
        print(contador)
        dir_raw=dir_raw.upper()
        if not isinstance(dir_raw, str) or dir_raw.strip() == "" \
        or "ZONA RURAL" in dir_raw.upper() \
        or "NO HAY" in dir_raw.upper() or "SIN D" in dir_raw.upper() or "NO SE E" in dir_raw.upper() or r"S/D" in dir_raw.upper() \
        or r"NO TIENE" in dir_raw.upper():
            continue

        for k, v in reemplazos.items():
            if k in dir_raw:
                dir_raw = dir_raw.replace(k, v, 1)  # solo el primero que aparezca
   

        base = dir_raw + ", Villa María, Córdoba, Argentina"

        location = geocode_direccion(base)

        if location:
            df=asignar_location(location,df,idx,dir_raw)



        else:
            # Extraemos el nombre bruto de la calle
            street = dir_raw.split(',')[0].strip()

            similares = buscar_calle_similar(street, calles, n=5, cutoff=0.6)               


            if similares:
                for calle in similares:
                    intento = f"{calle}, Villa María, Córdoba, Argentina"
                    loc2 = geocode_direccion(intento)
                    if loc2 and esta_en_villa_maria(loc2.latitude, loc2.longitude):
                        df.at[idx, 'lat'] = loc2.latitude
                        df.at[idx, 'lon'] = loc2.longitude
                        df.at[idx, 'WKT'] = f"POINT({loc2.longitude} {loc2.latitude})"
                        print(f"[ENCONTRADA POR SIMILARIDAD] {street} → {calle}: {intento} con LON {loc2.longitude} y LAT {loc2.latitude}")
                        break

                    # 2) Si no hubo match y es posible esquina, lo intentamos por Overpass

            elif is_intersection(dir_raw):
                print("Intersección",dir_raw)
                street1, street2 = split_intersection(dir_raw)
                location = geocode_direccion(street2)
                if location:
                    df=asignar_location(location,df,idx,street2)
                else:
                    inter = geocode_intersection_op(re.sub(r'\d+', '', street1), re.sub(r'\d+', '', street2))
                    print(inter,street1, street2)
                    if inter and esta_en_villa_maria(*inter):
                        lat, lon = inter
                        df.at[idx, 'lat'], df.at[idx, 'lon'] = lat, lon
                        df.at[idx, 'WKT'] = f"POINT({lon} {lat})"
                        print(f"[ENCONTRADA POR INTERSECCION] {street} → {inter}: con LON {loc2.longitude} y LAT {loc2.latitude}")
                        continue
                        

            else:
                print(f"[NO ENCONTRADA] Ninguna similar válida para '{street}'")

    return(df)

# %%
# if 'df_casos_conf' not in locals():   # existe en el scope local

#     ruta_excel = r"data\raw\No utiles\notificaciones dengue Villa María 23-24.xlsx"
#     df0 = pd.read_excel(ruta_excel)

#     ruta_excel = r"data\raw\No utiles\Notificaciones dengue Villa María 24-25.xlsx"
#     df1 = pd.read_excel(ruta_excel)
#     df_casos=pd.concat([df0,df1])

#     cols_utiles=['sexo',"edad_diagnostico","calle_domicilio","numero_domicilio","fecha_apertura",'clasificacion_manual']
#     df_casos=df_casos[cols_utiles]

#     # df=procesar_coordenadas(df)
#     df_casos_conf=df_casos.loc[(df_casos["clasificacion_manual"].str.contains("confirmado"))|
#                             (df_casos["clasificacion_manual"].str.contains("Caso de Dengue en brote con laboratorio"))]

#     df_casos_conf["DIRECCION"]=df_casos_conf["calle_domicilio"]+" "+df_casos_conf["numero_domicilio"]+", Villa María, Córdoba"
#     df_casos_conf=df_casos_conf.drop(["calle_domicilio","numero_domicilio","clasificacion_manual"],axis=1)
#     df_casos_conf.head()


from pathlib import Path
import pandas as pd

from pathlib import Path
import pandas as pd

from pathlib import Path
import pandas as pd

def cargar_casos_confirmados(
    dirpath_real="data/raw/casos_raw",        # carpeta con datos reales
    dirpath_samples="data/raw/samples",       # carpeta con SAMPLES (toda la carpeta)
    ciudad="Villa María, Córdoba",
    usecols=('sexo','edad_diagnostico','calle_domicilio','numero_domicilio','fecha_apertura','clasificacion_manual'),
    confirm_patterns=("confirmado", "caso de dengue en brote con laboratorio"),
):
    """
    1) Busca TODOS los archivos en 'dirpath_real' (xlsx/csv).
    2) Si no hay, busca TODOS los archivos en 'dirpath_samples' (xlsx/csv).
       (No un archivo llamado 'sample': recorre toda la carpeta y subcarpetas).
    3) Concatena, filtra confirmados y arma DIRECCION.
    4) Devuelve (DataFrame, etiqueta) con etiqueta ∈ {'real','_sample'}.
    """

    exts_ok = {".csv", ".xlsx", ".xls", ".xlsm"}

    def list_all_files(base_dir: str):
        base = Path(base_dir)
        if not base.exists():
            return []
        # rglob para recorrer subcarpetas; filtra por extensión válida y descarta temporales
        files = [
            p for p in base.rglob("*")
            if p.is_file()
            and p.suffix.lower() in exts_ok
            and not p.name.startswith("~$")      # evita archivos temporales de Excel
        ]
        # orden estable por ruta
        return sorted(files, key=lambda p: str(p).lower())

    def read_any(files):
        dfs = []
        for f in files:
            suff = f.suffix.lower()
            if suff in {".xlsx", ".xls", ".xlsm"}:
                df = pd.read_excel(
                    f,
                    sheet_name=0,
                    usecols=list(usecols),
                    engine="openpyxl",
                    dtype={"numero_domicilio": "string"},
                )
            elif suff == ".csv":
                df = pd.read_csv(
                    f,
                    usecols=list(usecols),
                    dtype={"numero_domicilio": "string"},
                    encoding="utf-8"
                )
            else:
                continue
            dfs.append(df)
        return dfs

    # -------- intenta reales primero --------
    files_real = list_all_files(dirpath_real)
    etiqueta = None
    dfs = []

    if files_real:
        dfs = read_any(files_real)
        etiqueta = "real"
    else:
        files_samples = list_all_files(dirpath_samples)
        if not files_samples:
            raise FileNotFoundError(
                "No se encontraron archivos válidos.\n"
                f"- Reales en: {Path(dirpath_real).resolve()}\n"
                f"- Samples en: {Path(dirpath_samples).resolve()}\n"
                "Se aceptan: CSV, XLSX, XLS, XLSM (se recorren todas las subcarpetas)."
            )
        dfs = read_any(files_samples)
        etiqueta = "sample"

    df_all = pd.concat(dfs, ignore_index=True)

    # -------- filtro confirmados --------
    clasif = df_all["clasificacion_manual"].fillna("").astype(str).str.casefold()
    mask = pd.Series(False, index=df_all.index)
    for pat in confirm_patterns:
        mask |= clasif.str.contains(str(pat).casefold())
    df = df_all.loc[mask, list(usecols)].copy()

    # -------- DIRECCION --------
    df["calle_domicilio"] = df["calle_domicilio"].fillna("").astype("string").str.strip()
    df["numero_domicilio"] = df["numero_domicilio"].fillna("").astype("string").str.strip()
    df["DIRECCION"] = (
        (df["calle_domicilio"] + " " + df["numero_domicilio"])
        .str.replace(r"\s+", " ", regex=True)
        .str.strip()
        + (", " + ciudad)
    )

    df["etiqueta"] = etiqueta
    df.drop(columns=["calle_domicilio", "numero_domicilio", "clasificacion_manual"], inplace=True)
    return df, etiqueta


# ejemplo:
df_casos_conf,label = cargar_casos_confirmados()
df_casos_conf.head()

print(f'utilizando_{label}')

ruta_excel_cc = rf"data\raw\casos_procesados\casos_direccion_{label}.xlsx"
casos_correctos = pd.read_excel(ruta_excel_cc)



df_sacar=pd.merge(df_casos_conf,casos_correctos[["DIRECCION","WKT"]],on="DIRECCION",how="left")   
lista=list(casos_correctos.loc[~casos_correctos["WKT"].isnull(),"DIRECCION"]) # aqui obtenemos los que WKT vacio, es decir que tengan una dirección con  lon, lat 
df_revisar=df_casos_conf.loc[~df_casos_conf["DIRECCION"].isin(lista)]
vacios=df_casos_conf.loc[df_casos_conf["DIRECCION"].isnull()]
print("A confirmar",len(lista),"casos")
df2=evaluar_direccion(df_revisar)
df2
# Out:
# utilizando_sample
# A confirmar 0 casos
# 1
# [ENCONTRADA] Dirección: ENTRE RÍOS 111, VILLA MARÍA, CÓRDOBA → Lat: -32.4196278, Lon: -63.2521062
# 2
# [ENCONTRADA] Dirección: CHACABUCO 185, VILLA MARÍA, CÓRDOBA → Lat: -32.4198876, Lon: -63.2652533
# 3
# [ENCONTRADA] Dirección: GENERAL PAZ 222, VILLA MARÍA, CÓRDOBA → Lat: -32.4089664, Lon: -63.2453805
# 4
# [ENCONTRADA] Dirección: TUCUMÁN 259, VILLA MARÍA, CÓRDOBA → Lat: -32.4205282, Lon: -63.2489665
# 5
# [ENCONTRADA] Dirección: JOSÉ INGENIEROS 296, VILLA MARÍA, CÓRDOBA → Lat: -32.4076935, Lon: -63.2447808
# 6
# [ENCONTRADA] Dirección: SARMIENTO 333, VILLA MARÍA, CÓRDOBA → Lat: -32.4206397, Lon: -63.2388393
# 7
# [ENCONTRADA] Dirección: BUENOS AIRES 370, VILLA MARÍA, CÓRDOBA → Lat: -32.4161552, Lon: -63.2510957
# 8
# [ENCONTRADA] Dirección: MENDOZA 407, VILLA MARÍA, CÓRDOBA → Lat: -32.4184827, Lon: -63.2480387
# 9
# [ENCONTRADA] Dirección: MITRE 444, VILLA MARÍA, CÓRDOBA → Lat: -32.4171723, Lon: -63.2425343
# 10
# [ENCONTRADA] Dirección: BUENOS AIRES 122, VILLA MARÍA, CÓRDOBA → Lat: -32.4177565, Lon: -63.2535228
# 11
# [ENCONTRADA] Dirección: MENDOZA 159, VILLA MARÍA, CÓRDOBA → Lat: -32.4201376, Lon: -63.2506449
# 12
# [ENCONTRADA] Dirección: MITRE 196, VILLA MARÍA, CÓRDOBA → Lat: -32.4147851, Lon: -63.2446413
# 13
# [ENCONTRADA] Dirección: ITALIA 233, VILLA MARÍA, CÓRDOBA → Lat: -32.4136254, Lon: -63.2529662
# 14
# [ENCONTRADA] Dirección: MARIANO MORENO 307, VILLA MARÍA, CÓRDOBA → Lat: -32.4165832, Lon: -63.2446324
# 15
# [ENCONTRADA POR SIMILARIDAD] SAN MARTIÍN 344 → San Martín: San Martín, Villa María, Córdoba, Argentina con LON -63.2250895 y LAT -32.4047805
# 16
# [ENCONTRADA] Dirección: CORRIENTES 381, VILLA MARÍA, CÓRDOBA → Lat: -32.3946418, Lon: -63.2127092
# 17
# [ENCONTRADA] Dirección: LA RIOJA 418, VILLA MARÍA, CÓRDOBA → Lat: -32.4118415, Lon: -63.2538177
# 18
# [ENCONTRADA] Dirección: MENDOZA 852, VILLA MARÍA, CÓRDOBA → Lat: -32.4154567, Lon: -63.2430574
# 19
# [ENCONTRADA] Dirección: CHACABUCO 257, VILLA MARÍA, CÓRDOBA → Lat: -32.4198876, Lon: -63.2652533
# 20
# [ENCONTRADA] Dirección: ITALIA 314, VILLA MARÍA, CÓRDOBA → Lat: -32.4126474, Lon: -63.253358
# 21
# [NO ENCONTRADA] Ninguna similar válida para 'BV. ALVEAR 371'
# 22
# [ENCONTRADA] Dirección: SARMIENTO 428, VILLA MARÍA, CÓRDOBA → Lat: -32.4206397, Lon: -63.2388393
#    sexo  edad_diagnostico fecha_apertura  \
# 0     F                 9     2023-01-22
# 2     F                23     2023-04-19
# 3     M                30     2023-05-03
# 4     F                37     2023-06-27
# 5     M                44     2023-07-14
# 6     F                51     2023-08-09
# 7     M                58     2023-09-25
# 8     F                65     2023-10-18
# 9     M                12     2023-12-04
# 10    M                10     2024-01-11
# 11    F                17     2024-02-28
# 12    M                24     2024-03-15
# 13    F                31     2024-04-09
# 15    F                45     2024-06-18
# 16    M                52     2024-07-07
# 17    F                59     2024-08-22
# 18    M                66     2024-10-03
# 19    F                13     2024-12-19
# 21    F                21     2025-03-02
# 22    M                30     2025-04-27
# 23    F                39     2025-06-11
# 24    M                48     2025-09-05
#
#                                     DIRECCION etiqueta        lon        lat  \
# 0        Entre Ríos 111, Villa María, Córdoba   sample -63.252106 -32.419628
# 2         Chacabuco 185, Villa María, Córdoba   sample -63.265253 -32.419888
# 3       General Paz 222, Villa María, Córdoba   sample -63.245381 -32.408966
# 4           Tucumán 259, Villa María, Córdoba   sample -63.248967 -32.420528
# 5   José Ingenieros 296, Villa María, Córdoba   sample -63.244781 -32.407694
# 6         Sarmiento 333, Villa María, Córdoba   sample -63.238839 -32.420640
# 7      Buenos Aires 370, Villa María, Córdoba   sample -63.251096 -32.416155
# 8           Mendoza 407, Villa María, Córdoba   sample -63.248039 -32.418483
# 9             Mitre 444, Villa María, Córdoba   sample -63.242534 -32.417172
# 10     Buenos Aires 122, Villa María, Córdoba   sample -63.253523 -32.417757
# 11          Mendoza 159, Villa María, Córdoba   sample -63.250645 -32.420138
# 12            Mitre 196, Villa María, Córdoba   sample -63.244641 -32.414785
# 13           Italia 233, Villa María, Córdoba   sample -63.252966 -32.413625
# 15   Mariano Moreno 307, Villa María, Córdoba   sample -63.244632 -32.416583
# 16      San Martiín 344, Villa María, Córdoba   sample -63.225090 -32.404781
# 17       Corrientes 381, Villa María, Córdoba   sample -63.212709 -32.394642
# 18         La Rioja 418, Villa María, Córdoba   sample -63.253818 -32.411842
# 19          Mendoza 852, Villa María, Córdoba   sample -63.243057 -32.415457
# 21        Chacabuco 257, Villa María, Córdoba   sample -63.265253 -32.419888
# 22           Italia 314, Villa María, Córdoba   sample -63.253358 -32.412647
# 23       Bv. Alvear 371, Villa María, Córdoba   sample        NaN        NaN
# 24        Sarmiento 428, Villa María, Córdoba   sample -63.238839 -32.420640
#
#                                WKT
# 0   POINT(-63.2521062 -32.4196278)
# 2   POINT(-63.2652533 -32.4198876)
# 3   POINT(-63.2453805 -32.4089664)
# 4   POINT(-63.2489665 -32.4205282)
# 5   POINT(-63.2447808 -32.4076935)
# 6   POINT(-63.2388393 -32.4206397)
# 7   POINT(-63.2510957 -32.4161552)
# 8   POINT(-63.2480387 -32.4184827)
# 9   POINT(-63.2425343 -32.4171723)
# 10  POINT(-63.2535228 -32.4177565)
# 11  POINT(-63.2506449 -32.4201376)
# 12  POINT(-63.2446413 -32.4147851)
# 13  POINT(-63.2529662 -32.4136254)
# 15  POINT(-63.2446324 -32.4165832)
# 16  POINT(-63.2250895 -32.4047805)
# 17  POINT(-63.2127092 -32.3946418)
# 18  POINT(-63.2538177 -32.4118415)
# 19  POINT(-63.2430574 -32.4154567)
# 21  POINT(-63.2652533 -32.4198876)
# 22   POINT(-63.253358 -32.4126474)
# 23                             NaN
# 24  POINT(-63.2388393 -32.4206397)

# %%
df44=df2.loc[~df2["lon"].isnull()]

df_final=pd.concat([casos_correctos,df44]).reset_index(drop=True)
df_final.to_excel(ruta_excel_cc, index=False)

# %%
import winsound

# Beep sencillo: frecuencia 1 kHz durante 500 ms

def hacer_sonido():
    winsound.Beep(1000, 1300)

hacer_sonido()

# %%
import overpy

api = overpy.Overpass()
query = """
area["boundary"="administrative"]["name"="Villa María"]["admin_level"="8"]->.searchArea;
way["highway"]["name"](area.searchArea);
out;
"""
result = api.query(query)

# extraer nombres únicos
calles_villa_maria = sorted({ way.tags["name"] for way in result.ways if "name" in way.tags })
# Out:
# ['1 de Mayo',
#  '12 de Octubre',
#  '17 de Agosto',
#  '2 de Abril',
#  '20 de Junio',
#  '25 de Mayo',
#  '27 de Setiembre',
#  '30 de Junio',
#  '9 de Julio',
#  'A. Yupanqui',
#  'Abelino Antuña',
#  'Abraham Ruiz',
#  'Acacia',
#  'Acapulco',
#  'Aconcagua',
#  'Aconquija',
#  'Adrián Otero',
#  'Aguirre Cámara',
#  'Agustin Tosco',
#  'Agustín Tosco',
#  'Agustín Álvarez',
#  'Aimé Painé',
#  'Alaska',
#  'Alberdi',
#  'Aldo Serrano',
#  'Alejandro Daniel Mie',
#  'Alejandro Errazquin',
#  'Alejandro Voglio',
#  'Alfonsina Storni',
#  'Aluminé',
#  'Amalia C. Figueredo',
#  'América',
#  'Antofalla',
#  'Antonio Berni',
#  'Antártida Argentina',
#  'Ara 17 de Octubre',
#  'Araucanos',
#  'Arenales',
#  'Arequipa',
#  'Arica',
#  'Artigas',
#  'Arturo M. Bas',
#  'Ascasubi',
#  'Asunción',
#  'Atahualpa Yupanqui',
#  'Atilio López',
#  'Av María Elena Walsh',
#  'Av. Los Algarrobos',
#  'Avellaneda',
#  'Avenida Aguará Guazú',
#  'Avenida Arturo Jauretche',
#  'Avenida Bruno Ceballos',
#  'Avenida Cardenal Amarillo',
#  'Avenida Costanera',
#  'Avenida De Los Pueblos Aborígenes',
#  'Avenida El Palmar',
#  'Avenida Elpidio Gonzáles',
#  'Avenida Fagnano',
#  'Avenida Francisco García',
#  'Avenida Garza Mora',
#  'Avenida General Savio',
#  'Avenida Granaderos Argentinos',
#  'Avenida Guillermo Rawson',
#  'Avenida Hipólito Buchardo',
#  'Avenida Hipólito Yrigoyen',
#  'Avenida Independencia',
#  'Avenida José Ingenieros',
#  'Avenida Juan José Massafra',
#  'Avenida Larrabure',
#  'Avenida Leandro N. Alem',
#  'Avenida Los Algarrobos',
#  'Avenida Luis Alberto Spinetta',
#  'Avenida María Eva Duarte de Perón',
#  'Avenida María Gabriela Epumer',
#  'Avenida Monseñor Alberto Deane',
#  'Avenida Monseñor Alfredo Guillermo Disandro',
#  'Avenida Monseñor Rodriguez',
#  'Avenida Naciones Unidas',
#  'Avenida Presidente Juan D. Perón',
#  'Avenida Presidente Juan Domingo Perón',
#  'Avenida Raúl Borras',
#  'Avenida Raúl Scalabrini Ortiz',
#  'Avenida Salomón Gornitz',
#  'Avenida Santa Ana',
#  'Avenida Universidad',
#  'Avenida Viviana Gómez de Gatario',
#  'Avenida del Libertador',
#  'Avenida del Libertador General San Martín',
#  'Aviso Ara Sobral',
#  'Ayacucho',
#  'Azcuénaga',
#  'Bahía',
#  'Baigorria',
#  'Balcarce',
#  'Bariloche',
#  'Bartolomé Mitre',
#  'Bautista Gianinetto',
#  'Berutti',
#  'Bicentenario',
#  'Bolivia',
#  'Bolívar',
#  'Boulevard Argentino - Raúl Ricardo Alfonsín',
#  'Boulevard Colón',
#  'Boulevard Dante Alighieri',
#  'Boulevard Italia',
#  'Boulevard Marcelo T. de Alvear',
#  'Boulevard Ramón Carcano',
#  'Boulevard Sarmiento',
#  'Boulevard Vélez Sarsfield',
#  'Brandsen',
#  'Brasil',
#  'Bruno Ceballos',
#  'Buchardo',
#  'Buenos Aires',
#  'Bulevar España',
#  'C. Pública',
#  'Calafate',
#  'Calchaquí',
#  'Cali',
#  'Calle 1',
#  'Calle 10',
#  'Calle 12',
#  'Calle 14',
#  'Calle 16',
#  'Calle 18',
#  'Calle 2',
#  'Calle 3',
#  'Calle 4',
#  'Calle 5',
#  'Calle 6',
#  'Calle 8',
#  'Camino a Rincón del Pino',
#  'Canadá',
#  'Caracas',
#  'Cardiel',
#  'Carlos Gardel',
#  'Carlos Pellegrini',
#  'Carlos Rocchi',
#  'Carola E. Lorenzini',
#  'Carpincho',
#  'Cartagena',
#  'Catamarca',
#  'Catedral',
#  'Caudillos Federales',
#  'Cecilia Grierson',
#  'Ceibo',
#  'Centenario',
#  'Cerros Colorados',
#  'Cervantes',
#  'Cesar Titina Bravin',
#  'Chacabuco',
#  'Chaco',
#  'Chajá',
#  'Champaquí',
#  'Chané',
#  'Charcas',
#  'Charrúas',
#  'Chascomús',
#  'Chañar',
#  'Chiclana',
#  'Chile',
#  'Chingolo',
#  'Christian "Polaco" Matcovich Telgarecz',
#  'Chubut',
#  'Chulupí',
#  'Churrinche',
#  'Ciclovía General Savio',
#  'Cina - Cina',
#  'Colectora',
#  'Colombia',
#  'Combate Darwin',
#  'Concejal Abel Aymar',
#  'Concejal Eduardo Cánova',
#  'Concejal Paradella',
#  'Concejal Ramón J. Gómez',
#  'Congreso',
#  'Constancio C. Vigil',
#  'Constituyentes',
#  'Corbeta Ara Guerrico',
#  'Coronilla',
#  'Corrientes',
#  'Costa Rica',
#  'Cr. Ricardo Podestá',
#  'Crucero Ara Belgrano',
#  'Cruz Roja Argentina',
#  'Curitiba',
#  'Cándido Serrano',
#  'César Citto',
#  'Córdoba',
#  'Daniel " Monky" Tieffemberg',
#  'Daniel Antonio Baysre',
#  'Daniel Loyola',
#  'Darwin',
#  'Darío David Ramonda',
#  'Demichelis',
#  'Derqui',
#  'Desvio Transito Pesado',
#  'Deán Funes',
#  'Diaguitas',
#  'Doctor Antonio Sobral',
#  'Doctor Sebastián Carbó',
#  'Dora Britos de Zárate',
#  'Echeverria',
#  'Ecuador',
#  'Edith Vera',
#  'El Chocón',
#  'El Rey',
#  'El Salvador',
#  'Elpidio Torres',
#  'Emiliano Gómez Clara',
#  'Emilio Pellegrini',
#  'Emilio Pettorutti',
#  'Empalme con Ruta 2',
#  'Encarnación Sobrino',
#  'Enrique Antonio Hoch - Héroe de Malvinas',
#  'Entre Ríos',
#  'Epuyén',
#  'Espinillo',
#  'Espora',
#  'Esquel',
#  'Estados Unidos',
#  'Estrada',
#  'Fangio',
#  'Favaloro',
#  'Fernando Bonfiglioli',
#  'Figueroa Alcorta',
#  'Fitz Roy',
#  'Florencio Campos',
#  'Florida',
#  'Formosa',
#  'Francia',
#  'Fray Mamerto Esquiú',
#  'French',
#  'Félix Negro',
#  'Gabriel Chalita',
#  'Gabriela Piaggio',
#  'Galería Jardín Baroque',
#  'Garay',
#  'Garibaldi',
#  'General Lonardi',
#  'General Paz',
#  'Gervasio Posadas',
#  'Gobernador Sabattini',
#  'Gorriti',
#  'Gral. Deheza',
#  'Gregoria Matorras',
#  'Guanacache',
#  'Guaraníes',
#  'Guatemala',
#  'Guayanas',
#  'Guayaquil',
#  'Guillermo Rawson',
#  'Guillermo Roldan',
#  'Guizzo',
#  'Gustavo Cerati',
#  'Haití',
#  'Heroes de Malvinas',
#  'Hipólito Yrigoyen',
#  'Honduras',
#  'Humahuaca',
#  'Héroes Ara San Juan',
#  'Iberá',
#  'Iguazú',
#  'Incahuasi',
#  'Incas',
#  'Independencia',
#  'Indios Patagones',
#  'Intendente Arines',
#  'Intendente Carlos Pizzorno',
#  'Intendente Correa',
#  'Intendente Díaz',
#  'Intendente E. Seydell',
#  'Intendente Horacio Luis Cabezas',
#  'Intendente José F. Perazolo',
#  'Intendente Maciel',
#  'Intendente Miguel Ángel Veglia',
#  'Intendente Peña',
#  'Intendente Poretti',
#  'Intendente Reyno',
#  'Intendente Urtubey',
#  'Intendente de la Colina',
#  'Isidro Fernández Núñez',
#  'Italia',
#  'Ituzaingó',
#  'Ivan "Nene" Miranda',
#  'Jarilla',
#  'Joaquín Víctor González',
#  'Jorge Amadeo Lencina “Héroe de Guerra”',
#  'Jorge Cafrune',
#  'Jorge Falcón',
#  'Jorge Luis Borges',
#  'Jorge Newbery',
#  'Jorge Omar Aisama "Héroe de Guerra"',
#  'José A. Iglesias',
#  'José Ignacio Rucci',
#  'José Ingenieros',
#  'José Marti',
#  'José Pedernera',
#  'José Riesco',
#  'Juan A. Espindola',
#  'Juan C. Mulinetti',
#  'Juan José Castelli',
#  'Juan José Hernandez Arregui',
#  'Juan Muller',
#  'Juana Azurduy',
#  'Juana Moro',
#  'Jujuy',
#  'Julio Cortázar',
#  'Julio Sosa',
#  'Junin',
#  'Juramento',
#  'Juárez Celman',
#  'Juárez Célman',
#  'La Arbolada 10',
#  'La Arbolada 11',
#  'La Arbolada 12',
#  'La Arbolada 14',
#  'La Arbolada 15',
#  'La Arbolada 4',
#  'La Arbolada 5',
#  'La Arbolada 6',
#  'La Arbolada 7',
#  'La Arbolada 8',
#  'La Arbolada 9',
#  'La Pampa',
#  'La Plata',
#  'La Quiaca',
#  'La Rioja',
#  'Lacar',
#  'Lago Argentino',
#  'Laguna Blanca',
#  'Lamadrid',
#  'Lanin',
#  'Las Bahamas',
#  'Las Heras',
#  'Las Magnolias',
#  'Las Palmas',
#  'Las Violetas',
#  'Laura Broggi de Maciel',
#  'Leonardo Favio',
#  'Leopoldo Lugones',
#  'Libertad',
#  'Liniers',
#  'Lino Eneas Spilimbergo',
#  'Lisandro de la Torre',
#  'Lisignoli',
#  'Logistica del Centro',
#  'Lolog',
#  'Los Abedules',
#  'Los Aromos',
#  'Los Ceibales',
#  'Los Cipreses',
#  'Los Fresnos',
#  'Los Glaciares',
#  'Los Lapachos',
#  'Los Ombúes',
#  'Los Paraisos',
#  'Los Pinares',
#  'Los Robles',
#  'Los Rosales',
#  'Los Sauces',
#  'Los Talas',
#  'Luis Audelino Juárez',
#  'Luis Federico Leloir',
#  'Luis Sandrini',
#  'Lule',
#  'López y Planes',
#  'Macacha Guemes',
#  'Madrid',
#  'Maestro Nicolás Ormeño',
#  'Maestros Argentinos',
#  'Mafalda C. Gilli',
#  'Magallanes',
#  'Maipo',
#  'Maipú',
#  'Malvinas Argentinas',
#  'Manuel Abuelo',
#  'Manuel Belgrano',
#  'Manuel Dorrego',
#  'Manuel Moreno',
#  'Manuel Ocampo',
#  'Mar del Plata',
#  'Maracaibo',
#  'Marcelino Cuello',
#  'Marcelo Alberto Duzevich - Héroe de Malvinas',
#  'Marcelo Javier Suppo',
#  'Marcelo Pierantonelli',
#  'Marcelo T. de Alvear',
#  'Marcos Juárez',
#  'Mariano Ceballos',
#  'Mariano Moreno',
#  'Marie Curie',
#  'Marina Luchini',
#  'Mariquita Sánchez de Thompson',
#  'Martín Fierro',
#  'Martínez Mendoza',
#  'Mary Amaya',
#  'Massetti',
#  'Matheu',
#  'Medellín',
#  'Mendoza',
#  'Mercedarios',
#  'Mercedes Sosa',
#  'Miguel Abuelo',
#  'Miguel Moreno',
#  'Miramar',
#  'Mirotti',
#  'Misiones',
#  'Mocoví',
#  'Molle',
#  'Monte Hermoso',
#  'Monteagudo',
#  'Monterrey',
#  'Moradillo',
#  'Muller',
#  'México',
#  'Nahuel Huapi',
#  'Necochea',
#  'Neuquén',
#  'Newton',
#  'Nicolás Sarno',
#  'Nueva Esperanza',
#  'Oil! Combustibles',
#  'Olegario Andrade',
#  'Omar Ramonda',
#  'Ombú',
#  'Ona',
#  'Orcadas Argentinas',
#  'Orlando Bassi',
#  'Oscar Vicente "Cacho" Palermo',
#  'Pablo Colabianchi',
#  'Panamá',
#  'Paraguay',
#  'Parajón Ortiz',
#  'Paraná',
#  'Pasaje Cabo Adrián Bustos',
#  'Pasaje Chazarreta',
#  'Pasaje Falucho',
#  'Pasaje Formosa',
#  'Pasaje Irineo Victori',
#  'Pasaje Ituzaingó',
#  'Pasaje J. M. Iturral',
#  'Pasaje José Hernández',
#  'Pasaje Lautaro',
#  'Pasaje Monti',
#  'Pasaje P. y Arregui',
#  'Pasaje Peatonal Don Pablo Barrelier',
#  'Pasaje Privado',
#  'Pasaje Privado A',
#  'Pasaje Privado B',
#  'Pasaje Ramón Campagna',
#  'Pasaje República',
#  'Pasaje Riera',
#  'Pasaje San Roque',
#  'Pasaje Yapeyú',
#  'Paseo Concejal Héctor Ángel Massel',
#  'Paseo Juan Pablo II',
#  'Paseo Vilma Perrachione',
#  'Paseo de la Villa',
#  'Pasionaria',
#  'Paso de Ferreyra',
#  'Paso de la Patria',
#  'Paso de los Andes',
#  'Paso de los Libres',
#  'Pasteur',
#  'Pastor Cesar Hector Oviedo',
#  'Patagones',
#  'Paul Groussac',
#  'Paysandú',
#  'País Vasco',
#  'Peatonal San Martín',
#  'Pereyra',
#  'Periodistas Argentinos',
#  'Perito Moreno',
#  'Perú',
#  'Piedras',
#  'Pilagás',
#  'Pilcomayo',
#  'Piscis',
#  'Porfirio Seppey',
#  'Presidente Doctor Arturo Illia',
#  'Primera Junta',
#  'Pringles',
#  'Pro. Corrientes',
#  'Pro. Entre Ríos',
#  'Pro. Mendoza',
#  'Pro. Tucumán',
#  'Prof. Miguel "Chiche" Bravo',
#  'Profesora Adelina Barela de Martilotti',
#  'Profesora Lelia Repetto de Foguet',
#  'Profesora Norma Ninina Tais',
#  'Progreso',
#  'Providencia',
#  'Provincias Unidas',
#  'Puelches',
#  'Puelo',
#  'Puente Brigadier Juan Bautista Bustos',
#  'Puente Juan B. Alberdi',
#  'Puente Juan Domingo Perón',
#  'Puente caído',
#  'Puerto Argentina',
#  'Puerto Mont',
#  'Puerto Rico',
#  'Pueyrredón',
#  'Querandí',
#  'Quillén',
#  'Quinquela Martín',
#  'Quintana',
#  'Quito',
#  'Ramiro Suarez',
#  'Ramos Mejía',
#  'Ramón Campagna',
#  'Rankulche',
#  'Ranqueles',
#  'Rebeca Gerschman',
#  'Recife',
#  'Reconquista',
#  'Remedios de Escalada',
#  'República de Cuba',
#  'República de Israel',
#  'República de Siria',
#  'República del Líbano',
#  'Requena',
#  'Ricardo José Neri',
#  'Richard Erdwin Santoni',
#  'Rio Cuarto',
#  'Rio Parana',
#  'Rivadavia',
#  'Rivera Indarte',
#  'Rochi',
#  'Rodolfo Walsh',
#  'Roma',
#  'Romano Ferrari',
#  'Román Deheza',
#  'Rondeau',
#  'Rosario Vera Peñaloza',
#  'Rosita Corbari',
#  'Ruta 3 General José Gervasio Artigas',
#  'Ruta Nacional 158',
#  'Ruta Nacional 1V09',
#  'Ruta Provincial 2',
#  'Río Carcarañá',
#  'Río Chubut',
#  'Río Colorado',
#  'Río Desaguadero',
#  'Río Deseado',
#  'Río Dulce',
#  'Río Limay',
#  'Río Mendoza',
#  'Río Negro',
#  'Río Salado',
#  'Río Salí',
#  'Río Segundo',
#  'Río Suquía',
#  'Río Tercero',
#  'Río Tunuyán',
#  'Río Uruguay',
#  'Saavedra',
#  'Sabiá',
#  'Saint Exupery',
#  'Sal de Indio',
#  'Salomón Deiver',
#  'Salomón Gornitz',
#  'Salta',
#  'Salto Grande',
#  'San Juan',
#  'San Lorenzo',
#  'San Luis',
#  'San Martín',
#  'Sanavirón',
#  'Sandro (Roberto Sánchez)',
#  'Santa Cruz',
#  'Santa Fe',
#  'Santa Lucía',
#  'Santa Marta',
#  'Santiago Balerdi',
#  'Santiago del Estero',
#  'Sara Rietti',
#  'Sargento Cabral',
#  'Sargento Primero José L. Morano',
#  'Sarratea',
#  'Silvia del V. García',
#  'Soldados Argentinos',
#  'Soler',
#  'Solís',
#  'Sucre',
#  'Suiza',
#  'Sáenz Peña',
#  'Tacuarí',
#  'Tala',
#  'Tehuelches',
#  'Teniente Ibáñez',
#  'Tierra del Fuego',
#  'Timbó',
#  'Tobas',
#  'Tomás Edison',
#  'Traful',
#  'Transito Pesado',
#  'Tromen',
#  'Tronador',
#  'Tucumán',
#  'Tunel Ferroviario Hermanos Seco',
#  'Tupungato',
#  'Uritorco',
#  'Uruguay',
#  'Ushuaia',
#  'Uspallata',
#  'Valparaiso',
#  'Venezuela',
#  'Veracruz',
#  'Viamonte',
#  'Victoria Ocampo',
#  'Victoria Romero de Peñaloza',
#  'Victorino de la Plaza',
#  'Viedma',
#  'Viena',
#  'Viña del Mar',
#  'Víctor Mercante',
#  'Walt Disney',
#  'Yaragundi',
#  'Zorzal',
#  'calle pública',
#  'chaco',
#  'circunvalación proyectada',
#  'combate San Carlos',
#  'darsena de camiones en construcción',
#  'darsena de camiones en cosntrucción',
#  'Ángel Benito Cámpora',
#  'Ástor Piazzolla']

# %%
api = overpy.Overpass()
query = """
area["boundary"="administrative"]["name"="Villa Nueva"]["admin_level"="8"]->.searchArea;
way["highway"]["name"](area.searchArea);
out;
"""
result = api.query(query)

# extraer nombres únicos
calles_villa_nueva = sorted({ way.tags["name"] for way in result.ways if "name" in way.tags })
# Out:
# ['10 de Junio',
#  '12 de Octubre',
#  '2 de Abril',
#  '2 de Setiembre',
#  '25 de Mayo',
#  '26 de Septiembre',
#  '31 de Octubre',
#  '4 de Septiembre',
#  '5 de Julio',
#  '8 de Octubre',
#  '9 de Julio',
#  'A. Moreno',
#  'Alberdi',
#  'Alfredo Palacios',
#  'Alheli',
#  'Alicia Moreau de Justo',
#  'Almirante Brown',
#  'Alvear',
#  'Ambrosio Olmos',
#  'Antártida Argentina',
#  'Atacama',
#  'Atahualpa Yupanqui',
#  'Avellaneda',
#  'Avenida Arturo Humberto Illia',
#  'Avenida C. Atlántica',
#  'Avenida Carranza',
#  'Avenida Cervantes',
#  'Avenida Costanera',
#  'Avenida Gardenias',
#  'Avenida Henry Néstle',
#  'Avenida Juan Domingo Peron',
#  'Avenida La Pichona',
#  'Avenida Las Fresias',
#  'Avenida Las Violetas',
#  'Avenida Los Arrayanes',
#  'Avenida Los Ceibos',
#  'Avenida Los Gigantes',
#  'Avenida Los Lirios',
#  'Avenida Patria',
#  'Avenida Tilcara',
#  'Azucenas',
#  'Barberis',
#  'Bartolomé Mitre',
#  'Belgrano',
#  'Bolivar',
#  'Bosque Monte Blanco',
#  'Bosque de Araucarias',
#  'Bosque de Caldén',
#  'Bosque de Hayas',
#  'Bosque de Pataia',
#  'Bosque de Pehuen',
#  'Boulevard Dante Alighieri',
#  'Buenos Aires',
#  'Bulevar Argentino',
#  'Bulevar Don Antonio',
#  'Bulevar La Pichona',
#  'C.F. Tulian',
#  'Calchaqui',
#  'Caranday',
#  'Cariló',
#  'Carlos Pelegrini',
#  'Catamarca',
#  'Cda P. Bufarini',
#  'Cerro Aconcagua',
#  'Cerro Catedral',
#  'Cerro Champaquí',
#  'Cerro Lanin',
#  'Cerro Monte Olivia',
#  'Cerro Tronador',
#  'Chacabuco',
#  'Chaco',
#  'Chapadmalal',
#  'Chubut',
#  'Claromecó',
#  'Colón',
#  'Comercio',
#  'Corrientes',
#  'Cortada 7 de Octubre',
#  'Cortada Caritas',
#  'Cortada Evaristo Arias',
#  'Cortada Fernando Freyte',
#  'Cortada Pablo Granado',
#  'Cortada Paso de Ferreyra',
#  'Córdoba',
#  'Derqui',
#  'Deán Funes',
#  'Eduardo Daniele',
#  'El Aguaribay',
#  'El Escultor',
#  'El Jacaranda',
#  'El Mercantil',
#  'Elvio Spinelli',
#  'Entre Ríos',
#  'España',
#  'Esteban Echeverria',
#  'Eva Perón',
#  'Figueroa Alcorta',
#  'Flor de Iris',
#  'Florida',
#  'Formosa',
#  'Francia',
#  'García Lorca',
#  'General Paz',
#  'Gerbera',
#  'González Camadero',
#  'Hilario Ascasubi',
#  'Hipólito Yrigoyen',
#  'Hornillos',
#  'Humahuaca',
#  'Independencia',
#  'Intendente Paviotti',
#  'Isabel la Católica',
#  'Isidro Fernández Núñez',
#  'Italia',
#  'Ituzaingó',
#  'Ivira',
#  'José Hernández',
#  'José Ingenieros',
#  'José Luis Cabezas',
#  'José Luis Sarasa',
#  'Juana Manso',
#  'Juarez Celman',
#  'Jujuy',
#  'Justo José de Urquiza',
#  'La Alameda',
#  'La Pampa',
#  'La Quiaca',
#  'La Rioja',
#  'Lago Aluminé',
#  'Lago Blanco',
#  'Lago Cardiel',
#  'Lago Correntoso',
#  'Lago Epuyen',
#  'Lago Escondido',
#  'Lago Fagnano',
#  'Lago Fontana',
#  'Lago Gutiérrez',
#  'Lago Hermoso',
#  'Lago Lacar',
#  'Lago Martin',
#  'Lago Mascardi',
#  'Lago Muster',
#  'Lago Nahuel Huapi',
#  'Lago Puelo',
#  'Lago Quillen',
#  'Lago Traful',
#  'Laprida',
#  'Las Acacias',
#  'Las Amapolas',
#  'Las Azaleas',
#  'Las Azucenas',
#  'Las Calandrias',
#  'Las Camelias',
#  'Las Dalias',
#  'Las Gaviotas',
#  'Las Hortensias',
#  'Las Orquídeas',
#  'Las Palmeras',
#  'Las Toninas',
#  'Lavanda',
#  'Leandro N. Alem',
#  'Libertad',
#  'Lima',
#  'Lisandro de la Torre',
#  'Los Abedules',
#  'Los Alerces',
#  'Los Algarrobos',
#  'Los Aromitos',
#  'Los Caldenes',
#  'Los Canarios',
#  'Los Chañares',
#  'Los Cocos',
#  'Los Colibries',
#  'Los Espinillos',
#  'Los Eucaliptos',
#  'Los Flamencos',
#  'Los Fresnos',
#  'Los Gladiolos',
#  'Los Jacintos',
#  'Los Jazmines',
#  'Los Jigleros',
#  'Los Lapachos',
#  'Los Nogales',
#  'Los Olivares',
#  'Los Paraisos',
#  'Los Pinos',
#  'Los Plátanos',
#  'Los Quebrachos',
#  'Los Robles',
#  'Los Talas',
#  'Los Tilos',
#  'Los Tulipanes',
#  'Los Zorzales',
#  'Luciana Vaudagnotto',
#  'Lucio Mansilla',
#  'Luis Vernet',
#  'López y Planes',
#  'Maimara',
#  'Maipú',
#  'Malvinas Argentinas',
#  'Manuel Mujica Láinez',
#  'Manuel de Falla',
#  'Mar Chiquita',
#  'Mar de Ajó',
#  'Mar de las Pampas',
#  'Mar del Plata',
#  'Marcos Juárez',
#  'Mendoza',
#  'Miramar',
#  'Misiones',
#  'Modesto Moreno',
#  'Monte Hermoso',
#  'Monte Piscis',
#  'Moradillo',
#  'Namumcurá',
#  'Necochea',
#  'Neuquén',
#  'Padre Hugo Salvato',
#  'Paraguay',
#  'Pasaje Charrua',
#  'Pasaje Tehuelche',
#  'Pasionaria',
#  'Paula Albarracín',
#  'Pedro de Mendoza',
#  'Piedras',
#  'Pinamar',
#  'Presidente Perón',
#  'Primero de Mayo',
#  'Pueblos Originarios',
#  'Puente Brigadier Juan Bautista Bustos',
#  'Puente Juan B. Alberdi',
#  'Puente Juan Domingo Perón',
#  'Puerto Argentino',
#  'Punta Mogotes',
#  'Purmamarca',
#  'Querandi',
#  'Ramón José Cárcano',
#  'Raúl Ricardo Alfonsín',
#  'Regina Pie de Casas',
#  'Ricardo Balbín',
#  'Rio Negro',
#  'Rivadavia',
#  'Rivero',
#  'Roldán',
#  'Ruta Provincial 2',
#  'Ruta Provincial 4',
#  'Saavedra',
#  'Salta',
#  'San Bernardo',
#  'San Cayetano',
#  'San Clemente del Tuyú',
#  'San Juan',
#  'San Lorenzo',
#  'San Luis',
#  'San Martín',
#  'San Roque',
#  'Santa Clara del Mar',
#  'Santa Cruz',
#  'Santa Fe',
#  'Santa Teresita',
#  'Santiago del Estero',
#  'Sarmiento',
#  'Siempreviva',
#  'Soldado Carlos Daniel Ferreyra',
#  'Soldado Daniel Leon Reina',
#  'Sombra de Toro',
#  'Sáenz Peña',
#  'Tabaquillo',
#  'Tala',
#  'Toba',
#  'Tucumán',
#  'Varas Alonso',
#  'Velez Sarsfield',
#  'Verbenas',
#  'Victoria Ocampo',
#  'Villa Gesell',
#  'Villamonte',
#  'Ñandubay']
