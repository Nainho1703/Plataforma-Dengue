# %%
import sqlite3
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderUnavailable
import time
import difflib
import overpy
import warnings
import numpy as np
import unicodedata

warnings.filterwarnings("ignore")


def esta_en_villa_maria(lat, lon):
    return (-33 <= lat <= -29) and (-65 <= lon <= -63)

geolocator = Nominatim(user_agent="vm_dengue_mapper", timeout=20)
# Función con backoff progresivo y control de errores
def geocode_direccion(direccion, max_retries=5):
    delay = 2
    for intento in range(1, max_retries + 1):
        try:
            # print(f"[BUSCANDO] {direccion} (intento {intento})")
            time.sleep(delay)
            return geolocator.geocode(direccion)
        except (GeocoderTimedOut, GeocoderUnavailable) as e:
            print(f"[REINTENTO] {direccion} → {str(e)}")
            time.sleep(delay)
            delay *= 2  # Exponencial: 2, 4, 8...
        except Exception as e:
            print(f"[FALLO FATAL] {direccion} → {str(e)}")
            break
    return None



# — Obtención de la lista de calles con Overpass —
api = overpy.Overpass()
query = """
area["boundary"="administrative"]["name"="Villa María"]["admin_level"="8"]->.searchArea;
way["highway"]["name"](area.searchArea);
out;
"""
result = api.query(query)
calles = sorted({ way.tags["name"] for way in result.ways if "name" in way.tags })
import unicodedata
def normalize(texto: str) -> str:
    """
    Quita acentos y otros diacríticos, pero preserva la ñ, y convierte a mayúsculas.
    """
    # 1. Descomponer en NFKD (“ñ” para ñ, “á” para á, etc.)
    nfkd = unicodedata.normalize('NFKD', texto)
    out_chars = []
    prev = None

    for c in nfkd:
        if unicodedata.combining(c):
            # Sólo dejamos la tilde (~) si va sobre una 'n' o 'N'
            if c == '\u0303' and prev and prev.lower() == 'n':
                out_chars.append(c)
            # resto de diacríticos los descartamos
        else:
            out_chars.append(c)
            prev = c

    # 2. Unir, pasar a mayúsculas y recomponer (NFC) para que 'N'+~ vuelva a ser 'Ñ'
    result = ''.join(out_chars).upper()
    return unicodedata.normalize('NFC', result)

def buscar_calle_similar(texto, lista_calles, n=5, cutoff=0.6):
    # Normalizamos lista de calles
    originales = lista_calles
    normalized_calles = [normalize(c) for c in originales]
    target = normalize(texto)
    # Buscamos coincidencias en la forma normalizada
    matches = difflib.get_close_matches(target, normalized_calles, n=n, cutoff=cutoff)
    # Reconstruimos los nombres con acento original
    return [ originales[normalized_calles.index(m)] for m in matches ]

def procesar_coordenadas(df, lon_col='lon', lat_col='lat', wkt_col='WKT'):
    # 1. Detectar filas donde 'lon' contiene dos valores separados por coma
    mask = df[lon_col].astype(str).str.contains(',', na=False)

    # 2. Si no hay ninguna fila con coma, devolvemos el df sin cambios
    if not mask.any():
        return df

    # 3. Split y renombrado de columnas temporales

    
    split = (
        df.loc[mask, lon_col]
          .astype(str)
          .str.split(',', expand=True)
          .rename(columns={0: lat_col, 1: lon_col})
    )

    # 4. Limpiar espacios y convertir a float
    split[lat_col] = split[lat_col].str.replace('"','').str.strip().astype(float)
    split[lon_col] = split[lon_col].str.replace('"','').str.strip().astype(float)

    # 5. Asignar de vuelta al df original
    df.loc[mask, lat_col] = split[lat_col]
    df.loc[mask, lon_col] = split[lon_col]

    # 6. Generar la columna WKT
    df[wkt_col] = df.apply(
        lambda row: f"POINT({row[lon_col]} {row[lat_col]})"
                    if pd.notna(row[lon_col]) and pd.notna(row[lat_col])
                    else pd.NA,
        axis=1
    )

    return df
def geocode_intersection_op(street1, street2, area_name="Villa María"):
    query = f"""
    area["boundary"="administrative"]["name"="{area_name}"]->.a;
    way(area.a)["highway"]["name"="{street1}"]->.w1;
    way(area.a)["highway"]["name"="{street2}"]->.w2;
    node(w1.w2)->.n;
    out body n 1;
    """
    try:
        res = api.query(query)
        if res.nodes:
            n = res.nodes[0]
            return float(n.lat), float(n.lon)
    except Exception:
        pass
    return None
def is_intersection(addr):
    a = addr.lower()
    return " y " in a or " esq. " in a or " esq " in a

def split_intersection(addr):
    low = addr.lower()
    if " y " in low:
        parts = low.split(" y ", 1)
    elif " esq. " in low:
        parts = low.split(" esq. ", 1)
    else:
        parts = low.split(" esq ", 1)
    print(parts)
    return parts[0].strip().capitalize(), parts[1].strip().capitalize()

import numpy as np
import re


def asignar_location(location,df,idx,dir_raw,mensaje=0):
    lat = location.latitude
    lon = location.longitude
    
    if not esta_en_villa_maria(lat, lon):
        print(f"[ERROR GEO] Coordenadas fuera de Villa María: {dir_raw} → Lat: {lat}, Lon: {lon}")


    wkt = f"POINT({lon} {lat})"
    df.at[idx, 'lat'] = lat
    df.at[idx, 'lon'] = lon
    df.at[idx, 'WKT'] = wkt
    if mensaje==1:
        print(f"[ENCONTRADA] Dirección 2: {dir_raw} → Lat: {lat}, Lon: {lon}")
    else:
        print(f"[ENCONTRADA] Dirección: {dir_raw} → Lat: {lat}, Lon: {lon}")
    return df
def evaluar_direccion(df,columna_direccion="DIRECCION"):
    
    # Inicializar geocoder
   
    if "lon" not in df.columns:
        df["lon"]=np.nan
    # Filas con lon vacía
    faltantes = df[df['lon'].isna()].copy()

    # Si no hay una columna de dirección clara, asumimos una posible:

    contador=0

    reemplazos={'TTE.':'TENIENTE','INT':'INTENDENTE',"MEJICO":"MEXICO",'Antonio Hosch':'Enrique Antonio Hoch','Enrique A. Hoch':'Enrique Antonio Hoch',
                'T. PEÑA':"INTENDENTE PEÑA","EEUU":"ESTADOS UNIDOS",'BV ALVEAR':'Boulevard Marcelo T. de Alvear','CTDA. ': ""}
    for idx, row in faltantes.iterrows():
        contador += 1
        dir_raw = row[columna_direccion]
        print(contador)
        dir_raw=dir_raw.upper()
        if not isinstance(dir_raw, str) or dir_raw.strip() == "" \
        or "ZONA RURAL" in dir_raw.upper() \
        or "NO HAY" in dir_raw.upper() or "SIN D" in dir_raw.upper() or "NO SE E" in dir_raw.upper() or r"S/D" in dir_raw.upper() \
        or r"NO TIENE" in dir_raw.upper():
            continue

        for k, v in reemplazos.items():
            if k in dir_raw:
                dir_raw = dir_raw.replace(k, v, 1)  # solo el primero que aparezca
   

        base = dir_raw + ", Villa María, Córdoba, Argentina"

        location = geocode_direccion(base)

        if location:
            df=asignar_location(location,df,idx,dir_raw)



        else:
            # Extraemos el nombre bruto de la calle
            street = dir_raw.split(',')[0].strip()

            similares = buscar_calle_similar(street, calles, n=5, cutoff=0.6)               


            if similares:
                for calle in similares:
                    intento = f"{calle}, Villa María, Córdoba, Argentina"
                    loc2 = geocode_direccion(intento)
                    if loc2 and esta_en_villa_maria(loc2.latitude, loc2.longitude):
                        df.at[idx, 'lat'] = loc2.latitude
                        df.at[idx, 'lon'] = loc2.longitude
                        df.at[idx, 'WKT'] = f"POINT({loc2.longitude} {loc2.latitude})"
                        print(f"[ENCONTRADA POR SIMILARIDAD] {street} → {calle}: {intento} con LON {loc2.longitude} y LAT {loc2.latitude}")
                        break

                    # 2) Si no hubo match y es posible esquina, lo intentamos por Overpass

            elif is_intersection(dir_raw):
                print("Intersección",dir_raw)
                street1, street2 = split_intersection(dir_raw)
                location = geocode_direccion(street2)
                if location:
                    df=asignar_location(location,df,idx,street2)
                else:
                    inter = geocode_intersection_op(re.sub(r'\d+', '', street1), re.sub(r'\d+', '', street2))
                    print(inter,street1, street2)
                    if inter and esta_en_villa_maria(*inter):
                        lat, lon = inter
                        df.at[idx, 'lat'], df.at[idx, 'lon'] = lat, lon
                        df.at[idx, 'WKT'] = f"POINT({lon} {lat})"
                        print(f"[ENCONTRADA POR INTERSECCION] {street} → {inter}: con LON {loc2.longitude} y LAT {loc2.latitude}")
                        continue
                        

            else:
                print(f"[NO ENCONTRADA] Ninguna similar válida para '{street}'")

    return(df)

# %%
if 'df_casos_conf' not in locals():   # existe en el scope local

    ruta_excel = r"Datos\Casos\No utiles\notificaciones dengue Villa María 23-24.xlsx"
    df0 = pd.read_excel(ruta_excel)

    ruta_excel = r"Datos\Casos\No utiles\Notificaciones dengue Villa María 24-25.xlsx"
    df1 = pd.read_excel(ruta_excel)
    df_casos=pd.concat([df0,df1])

    cols_utiles=['sexo',"edad_diagnostico","calle_domicilio","numero_domicilio","fecha_apertura",'clasificacion_manual']
    df_casos=df_casos[cols_utiles]

    # df=procesar_coordenadas(df)
    df_casos_conf=df_casos.loc[(df_casos["clasificacion_manual"].str.contains("confirmado"))|
                            (df_casos["clasificacion_manual"].str.contains("Caso de Dengue en brote con laboratorio"))]

    df_casos_conf["DIRECCION"]=df_casos_conf["calle_domicilio"]+" "+df_casos_conf["numero_domicilio"]+", Villa María, Córdoba"
    df_casos_conf=df_casos_conf.drop(["calle_domicilio","numero_domicilio","clasificacion_manual"],axis=1)
    df_casos_conf.head()





ruta_excel_cc = r"Datos\Casos\No utiles\Casos Direccion Correcta.xlsx"
casos_correctos = pd.read_excel(ruta_excel_cc)



df_sacar=pd.merge(df_casos_conf,casos_correctos[["DIRECCION","WKT"]],on="DIRECCION",how="left")
lista=list(casos_correctos.loc[~casos_correctos["WKT"].isnull(),"DIRECCION"])
df_revisar=df_casos_conf.loc[~df_casos_conf["DIRECCION"].isin(lista)]
vacios=df_casos_conf.loc[df_casos_conf["DIRECCION"].isnull()]
len(df_casos_conf),len(df_casos_conf)-len(lista)-len(vacios)

df2=evaluar_direccion(df_revisar)
df2
# Out:
# 1
# [ENCONTRADA] Dirección: LA PAMPA 2247, VILLA MARÍA, CÓRDOBA → Lat: -32.4094327, Lon: -63.2253577
# 2
# [ENCONTRADA] Dirección: INTENDENTE PEÑA 8710, VILLA MARÍA, CÓRDOBA → Lat: -32.4001128, Lon: -63.2357674
# 3
# [NO ENCONTRADA] Ninguna similar válida para 'RUTA 9 KM 562 0'
# 4
# [NO ENCONTRADA] Ninguna similar válida para 'NICOLÁS AVELLANEDA      SAN PABLO 2650'
# 5
# 6
# [NO ENCONTRADA] Ninguna similar válida para 'NOLBERTO GUIZZO 1058'
# 7
# [NO ENCONTRADA] Ninguna similar válida para 'S.J. BAUTISTA - LAS HERAS 2546'
# 8
# [NO ENCONTRADA] Ninguna similar válida para 'ISLAS BALEARES 774'
# 9
# [ENCONTRADA] Dirección: ANTUÑA 65, VILLA MARÍA, CÓRDOBA → Lat: -32.4038689, Lon: -63.2302257
# 10
# [NO ENCONTRADA] Ninguna similar válida para 'R. JUAREZ 1459'
# 11
# [NO ENCONTRADA] Ninguna similar válida para 'RAMIRO SUAREZ BARRIO ALMIRANTE BROWN 1392'
# 12
# [ENCONTRADA] Dirección: Boulevard Marcelo T. de Alvear 411, VILLA MARÍA, CÓRDOBA → Lat: -32.412156, Lon: -63.2352895
# 13
# [NO ENCONTRADA] Ninguna similar válida para 'PERAZOLLO 211'
# 14
# [NO ENCONTRADA] Ninguna similar válida para 'OSCAR MONJES 1634'
# 15
# [NO ENCONTRADA] Ninguna similar válida para 'CENTRO - FLORIDA 961'
# 16
# Intersección PROLONG. BV. ITALIA ESQ. MARIA CURIE 1156, VILLA MARÍA, CÓRDOBA
# ['prolong. bv. italia', 'maria curie 1156, villa maría, córdoba']
# None Prolong. bv. italia Maria curie 1156, villa maría, córdoba
# 17
# [NO ENCONTRADA] Ninguna similar válida para 'MONSEÑOR ANTUÑA 48'
# 18
# [NO ENCONTRADA] Ninguna similar válida para 'SUCREYCOLINA 0'
# 19
# [NO ENCONTRADA] Ninguna similar válida para 'CORTADA NECOCHEA 925'
# 20
# [ENCONTRADA] Dirección: Boulevard Marcelo T. de Alvear 1275, VILLA MARÍA, CÓRDOBA → Lat: -32.419701, Lon: -63.2285542
# 21
# Intersección PROL. ALVEAR Y FRANCHINI 0, VILLA MARÍA, CÓRDOBA
# ['prol. alvear', 'franchini 0, villa maría, córdoba']
# None Prol. alvear Franchini 0, villa maría, córdoba
# 22
# Intersección PASTOR OVIEDO ESQ. F. ALCORTA 00, VILLA MARÍA, CÓRDOBA
# ['pastor oviedo', 'f. alcorta 00, villa maría, córdoba']
# None Pastor oviedo F. alcorta 00, villa maría, córdoba
# 23
# [ENCONTRADA] Dirección: ESTADOS UNIDOS 1247, VILLA MARÍA, CÓRDOBA → Lat: -32.4016104, Lon: -63.2588667
# 24
# 25
# [NO ENCONTRADA] Ninguna similar válida para 'ENRIQUE A. HOCH 358'
# 26
# [NO ENCONTRADA] Ninguna similar válida para 'ELISEO SORIA 486'
# 27
# [NO ENCONTRADA] Ninguna similar válida para 'DR. RENE FAVALORO 680'
# 28
# [NO ENCONTRADA] Ninguna similar válida para 'G PAZ 845'
# 29
# 30
# [NO ENCONTRADA] Ninguna similar válida para 'ANTONIO HOSCH 168'
# 31
# [NO ENCONTRADA] Ninguna similar válida para 'LACAR S/N PB MONOBLOCK 24'
# 32
# [NO ENCONTRADA] Ninguna similar válida para 'A M BAS 564'
# 33
# [ENCONTRADA] Dirección: Boulevard Marcelo T. de Alvear 555, VILLA MARÍA, CÓRDOBA → Lat: -32.4134476, Lon: -63.2341505
# 34
# [NO ENCONTRADA] Ninguna similar válida para 'PROL ALVEAR 3267'
# 35
# [ENCONTRADA] Dirección: Boulevard Marcelo T. de Alvear 846, VILLA MARÍA, CÓRDOBA → Lat: -32.4163017, Lon: -63.2318268
# 36
# [NO ENCONTRADA] Ninguna similar válida para 'SABATINI 490'
# 37
# [NO ENCONTRADA] Ninguna similar válida para 'SMITARELLO 386'
# 38
# [NO ENCONTRADA] Ninguna similar válida para 'BV. ESPAÑA 486 486'
# 39
# [NO ENCONTRADA] Ninguna similar válida para 'EE UU 635'
# 40
# [NO ENCONTRADA] Ninguna similar válida para 'BV.ARGENTINO 2110'
# 41
# [NO ENCONTRADA] Ninguna similar válida para 'BV.ESPAÑA 781 781'
# 42
# [NO ENCONTRADA] Ninguna similar válida para 'PROLONGACION ALVEAR 2543'
# 43
# [NO ENCONTRADA] Ninguna similar válida para 'BV COLON 1508'
# 44
# [NO ENCONTRADA] Ninguna similar válida para 'BS AS  1671'
# 45
# [NO ENCONTRADA] Ninguna similar válida para 'ISLAS BALEARES S/N 000 240'
# 46
# 47
# [NO ENCONTRADA] Ninguna similar válida para 'CTADA PAVIOTTI 91'
# 48
# [NO ENCONTRADA] Ninguna similar válida para 'B° LOS OLMOS - CALLE:ACONCAGUA 181'
# 49
# 50
# [NO ENCONTRADA] Ninguna similar válida para 'PROLONGACION ALVEAR 0'
# 51
# [NO ENCONTRADA] Ninguna similar válida para 'AV. SABIO 2440'
# 52
# [NO ENCONTRADA] Ninguna similar válida para 'PROLONG. ALVEAR 1333'
# 53
# [NO ENCONTRADA] Ninguna similar válida para 'MONSEÑOR ANTUNA 91'
# 54
# 55
# [NO ENCONTRADA] Ninguna similar válida para 'SIMON BOLIVAR 2289'
# 56
# [NO ENCONTRADA] Ninguna similar válida para 'AV. PERAZZOLO 626'
# 57
# Intersección ALVEAR Y FRANCHINI 0, VILLA MARÍA, CÓRDOBA
# ['alvear', 'franchini 0, villa maría, córdoba']
# None Alvear Franchini 0, villa maría, córdoba
# 58
# [NO ENCONTRADA] Ninguna similar válida para 'RUTA9KM563 00000'
# 59
# [NO ENCONTRADA] Ninguna similar válida para 'AV PERAZZOLO 678'
# 60
# [NO ENCONTRADA] Ninguna similar válida para 'SMITARELLO 323'
# 61
# [NO ENCONTRADA] Ninguna similar válida para 'GENERAL LAS HERAS 1619'
# 62
# [NO ENCONTRADA] Ninguna similar válida para 'M.MODESTO MORENO 1345'
# 63
# [NO ENCONTRADA] Ninguna similar válida para 'RUTA 9 BOLICHES LOS PALOS 0'
# 64
# [NO ENCONTRADA] Ninguna similar válida para 'CORTADA FORMOSA 2360'
# 65
# [NO ENCONTRADA] Ninguna similar válida para 'ZONARURAL 0'
# 66
# 67
# [NO ENCONTRADA] Ninguna similar válida para 'PUEBLOS ORIGINARIOS 1380'
# 68
# [NO ENCONTRADA] Ninguna similar válida para 'BV CARCANO 141'
# 69
# [NO ENCONTRADA] Ninguna similar válida para 'NINIA TAIS 2042'
# 70
# 71
# [NO ENCONTRADA] Ninguna similar válida para 'BV. ITALIA 1382'
# 72
# [NO ENCONTRADA] Ninguna similar válida para 'TTE-IBAÑEZ 2700'
# 73
# 74
# [NO ENCONTRADA] Ninguna similar válida para 'SMITARELLO 323'
# 75
# [NO ENCONTRADA] Ninguna similar válida para 'OSCAR MONJES 1634'
# 76
# [NO ENCONTRADA] Ninguna similar válida para 'PROL ALVEAR 3267'
# 77
# [NO ENCONTRADA] Ninguna similar válida para 'A M BAS 636'
# 78
# [NO ENCONTRADA] Ninguna similar válida para 'J J H ARREGUI 1259'
# 79
# [NO ENCONTRADA] Ninguna similar válida para 'AMBROSIO OLMOS  710'
# 80
# [NO ENCONTRADA] Ninguna similar válida para 'GRAL SIMON BOLIVAR 1375'
# 81
# [NO ENCONTRADA] Ninguna similar válida para 'PROL ALVEAR CHALET FERROVIARIO 0'
# 82
# [NO ENCONTRADA] Ninguna similar válida para 'PROLONGACION BV ITALIA 1270'
# 83
# Intersección TRAFUL ESQ MERCEDARIO 00, VILLA MARÍA, CÓRDOBA
# ['traful', 'mercedario 00, villa maría, córdoba']
# None Traful Mercedario 00, villa maría, córdoba
# 84
# [NO ENCONTRADA] Ninguna similar válida para 'PASAJE NECOCHEA 2045'
# 85
# [NO ENCONTRADA] Ninguna similar válida para 'RAESON 1982'
# 86
# [ENCONTRADA] Dirección: Boulevard Marcelo T. de Alvear 56, VILLA MARÍA, CÓRDOBA → Lat: -32.408964, Lon: -63.2386357
# 87
# [NO ENCONTRADA] Ninguna similar válida para 'PROL. ALVEAR 3400'
# 88
# 89
# [NO ENCONTRADA] Ninguna similar válida para 'RUCCHI | 254 DTO 9D 254'
#      sexo  edad_diagnostico fecha_apertura  \
# 443     F                56     2024-04-08
# 518     F                55     2024-04-11
# 584     F                52     2024-03-12
# 694     F                50     2024-04-08
# 704     F                49     2024-03-08
# ...   ...               ...            ...
# 3877    M                 0     2024-03-23
# 3884    M                75     2024-04-22
# 3895    M                77     2024-03-17
# 3914    M                48     2024-02-07
# 321     F                32     2025-04-21
#
#                                               DIRECCION        lon        lat  \
# 443           CTDA. LA PAMPA 2247, Villa María, Córdoba -63.225358 -32.409433
# 518                  T. Peña 8710, Villa María, Córdoba -63.235767 -32.400113
# 584               RUTA 9 KM 562 0, Villa María, Córdoba        NaN        NaN
# 694   Nicolás Avellaneda      San Pablo 2650, Villa ...        NaN        NaN
# 704   Zona Rural Villa Maria-Tio Pujio -, Villa Marí...        NaN        NaN
# ...                                                 ...        ...        ...
# 3877                  Raeson 1982, Villa María, Córdoba        NaN        NaN
# 3884                 BV ALVEAR 56, Villa María, Córdoba -63.238636 -32.408964
# 3895            PROL. ALVEAR 3400, Villa María, Córdoba        NaN        NaN
# 3914   Zona Rural Ruta 9 Km 548 -, Villa María, Córdoba        NaN        NaN
# 321       RUCCHI | 254 DTO 9D 254, Villa María, Córdoba        NaN        NaN
#
#                                  WKT
# 443   POINT(-63.2253577 -32.4094327)
# 518   POINT(-63.2357674 -32.4001128)
# 584                              NaN
# 694                              NaN
# 704                              NaN
# ...                              ...
# 3877                             NaN
# 3884   POINT(-63.2386357 -32.408964)
# 3895                             NaN
# 3914                             NaN
# 321                              NaN
#
# [89 rows x 7 columns]

# %%
df44=df2.loc[~df2["lon"].isnull()]
ruta_excel_cc = r"Datos\Casos\No utiles\Casos Direccion Correcta.xlsx"
df_final=pd.concat([casos_correctos,df44]).reset_index(drop=True)
df_final.to_excel(ruta_excel_cc, index=False)

# %%
import winsound

# Beep sencillo: frecuencia 1 kHz durante 500 ms

def hacer_sonido():
    winsound.Beep(1000, 1300)

hacer_sonido()

# %%
import overpy

api = overpy.Overpass()
query = """
area["boundary"="administrative"]["name"="Villa María"]["admin_level"="8"]->.searchArea;
way["highway"]["name"](area.searchArea);
out;
"""
result = api.query(query)

# extraer nombres únicos
calles = sorted({ way.tags["name"] for way in result.ways if "name" in way.tags })
calles
# Out:
# ['1 de Mayo',
#  '12 de Octubre',
#  '17 de Agosto',
#  '2 de Abril',
#  '20 de Junio',
#  '25 de Mayo',
#  '27 de Setiembre',
#  '30 de Junio',
#  '9 de Julio',
#  'A. Yupanqui',
#  'Abelino Antuña',
#  'Abraham Ruiz',
#  'Acacia',
#  'Acapulco',
#  'Aconcagua',
#  'Aconquija',
#  'Adrián Otero',
#  'Aguirre Cámara',
#  'Agustin Tosco',
#  'Agustín Tosco',
#  'Agustín Álvarez',
#  'Aimé Painé',
#  'Alaska',
#  'Alberdi',
#  'Aldo Serrano',
#  'Alejandro Daniel Mie',
#  'Alejandro Errazquin',
#  'Alejandro Voglio',
#  'Alfonsina Storni',
#  'Aluminé',
#  'Amalia C. Figueredo',
#  'América',
#  'Antofalla',
#  'Antonio Berni',
#  'Antártida Argentina',
#  'Ara 17 de Octubre',
#  'Araucanos',
#  'Arenales',
#  'Arequipa',
#  'Arica',
#  'Artigas',
#  'Arturo M. Bas',
#  'Ascasubi',
#  'Asunción',
#  'Atahualpa Yupanqui',
#  'Atilio López',
#  'Av María Elena Walsh',
#  'Av. Los Algarrobos',
#  'Avellaneda',
#  'Avenida Aguará Guazú',
#  'Avenida Arturo Jauretche',
#  'Avenida Bruno Ceballos',
#  'Avenida Cardenal Amarillo',
#  'Avenida Costanera',
#  'Avenida De Los Pueblos Aborígenes',
#  'Avenida El Palmar',
#  'Avenida Elpidio Gonzáles',
#  'Avenida Fagnano',
#  'Avenida Francisco García',
#  'Avenida Garza Mora',
#  'Avenida General Savio',
#  'Avenida Granaderos Argentinos',
#  'Avenida Guillermo Rawson',
#  'Avenida Hipólito Buchardo',
#  'Avenida Hipólito Yrigoyen',
#  'Avenida Independencia',
#  'Avenida José Ingenieros',
#  'Avenida Juan José Massafra',
#  'Avenida Larrabure',
#  'Avenida Leandro N. Alem',
#  'Avenida Los Algarrobos',
#  'Avenida Luis Alberto Spinetta',
#  'Avenida María Eva Duarte de Perón',
#  'Avenida María Gabriela Epumer',
#  'Avenida Monseñor Alberto Deane',
#  'Avenida Monseñor Alfredo Guillermo Disandro',
#  'Avenida Monseñor Rodriguez',
#  'Avenida Naciones Unidas',
#  'Avenida Presidente Juan D. Perón',
#  'Avenida Presidente Juan Domingo Perón',
#  'Avenida Raúl Borras',
#  'Avenida Raúl Scalabrini Ortiz',
#  'Avenida Salomón Gornitz',
#  'Avenida Santa Ana',
#  'Avenida Universidad',
#  'Avenida Viviana Gómez de Gatario',
#  'Avenida del Libertador',
#  'Avenida del Libertador General San Martín',
#  'Aviso Ara Sobral',
#  'Ayacucho',
#  'Azcuénaga',
#  'Bahía',
#  'Baigorria',
#  'Balcarce',
#  'Bariloche',
#  'Bartolomé Mitre',
#  'Bautista Gianinetto',
#  'Berutti',
#  'Bicentenario',
#  'Bolivia',
#  'Bolívar',
#  'Boulevard Argentino - Raúl Ricardo Alfonsín',
#  'Boulevard Colón',
#  'Boulevard Dante Alighieri',
#  'Boulevard Italia',
#  'Boulevard Marcelo T. de Alvear',
#  'Boulevard Ramón Carcano',
#  'Boulevard Sarmiento',
#  'Boulevard Vélez Sarsfield',
#  'Brandsen',
#  'Brasil',
#  'Bruno Ceballos',
#  'Buchardo',
#  'Buenos Aires',
#  'Bulevar España',
#  'C. Pública',
#  'Calafate',
#  'Calchaquí',
#  'Cali',
#  'Calle 1',
#  'Calle 10',
#  'Calle 12',
#  'Calle 14',
#  'Calle 16',
#  'Calle 18',
#  'Calle 2',
#  'Calle 3',
#  'Calle 4',
#  'Calle 5',
#  'Calle 6',
#  'Calle 8',
#  'Camino a Rincón del Pino',
#  'Canadá',
#  'Caracas',
#  'Cardiel',
#  'Carlos Gardel',
#  'Carlos Pellegrini',
#  'Carlos Rocchi',
#  'Carola E. Lorenzini',
#  'Carpincho',
#  'Cartagena',
#  'Catamarca',
#  'Catedral',
#  'Caudillos Federales',
#  'Cecilia Grierson',
#  'Ceibo',
#  'Centenario',
#  'Cerros Colorados',
#  'Cervantes',
#  'Cesar Titina Bravin',
#  'Chacabuco',
#  'Chaco',
#  'Chajá',
#  'Champaquí',
#  'Chané',
#  'Charcas',
#  'Charrúas',
#  'Chascomús',
#  'Chañar',
#  'Chiclana',
#  'Chile',
#  'Chingolo',
#  'Christian "Polaco" Matcovich Telgarecz',
#  'Chubut',
#  'Chulupí',
#  'Churrinche',
#  'Ciclovía General Savio',
#  'Cina - Cina',
#  'Colectora',
#  'Colombia',
#  'Combate Darwin',
#  'Concejal Abel Aymar',
#  'Concejal Eduardo Cánova',
#  'Concejal Paradella',
#  'Concejal Ramón J. Gómez',
#  'Congreso',
#  'Constancio C. Vigil',
#  'Constituyentes',
#  'Corbeta Ara Guerrico',
#  'Coronilla',
#  'Corrientes',
#  'Costa Rica',
#  'Cr. Ricardo Podestá',
#  'Crucero Ara Belgrano',
#  'Cruz Roja Argentina',
#  'Curitiba',
#  'Cándido Serrano',
#  'César Citto',
#  'Córdoba',
#  'Daniel " Monky" Tieffemberg',
#  'Daniel Antonio Baysre',
#  'Daniel Loyola',
#  'Darwin',
#  'Darío David Ramonda',
#  'Demichelis',
#  'Derqui',
#  'Desvio Transito Pesado',
#  'Deán Funes',
#  'Diaguitas',
#  'Doctor Antonio Sobral',
#  'Doctor Sebastián Carbó',
#  'Dora Britos de Zárate',
#  'Echeverria',
#  'Ecuador',
#  'Edith Vera',
#  'El Chocón',
#  'El Rey',
#  'El Salvador',
#  'Elpidio Torres',
#  'Emiliano Gómez Clara',
#  'Emilio Pellegrini',
#  'Emilio Pettorutti',
#  'Empalme con Ruta 2',
#  'Encarnación Sobrino',
#  'Enrique Antonio Hoch - Héroe de Malvinas',
#  'Entre Ríos',
#  'Epuyén',
#  'Espinillo',
#  'Espora',
#  'Esquel',
#  'Estados Unidos',
#  'Estrada',
#  'Fangio',
#  'Favaloro',
#  'Fernando Bonfiglioli',
#  'Figueroa Alcorta',
#  'Fitz Roy',
#  'Florencio Campos',
#  'Florida',
#  'Formosa',
#  'Francia',
#  'Fray Mamerto Esquiú',
#  'French',
#  'Félix Negro',
#  'Gabriel Chalita',
#  'Gabriela Piaggio',
#  'Galería Jardín Baroque',
#  'Garay',
#  'Garibaldi',
#  'General Lonardi',
#  'General Paz',
#  'Gervasio Posadas',
#  'Gobernador Sabattini',
#  'Gorriti',
#  'Gral. Deheza',
#  'Gregoria Matorras',
#  'Guanacache',
#  'Guaraníes',
#  'Guatemala',
#  'Guayanas',
#  'Guayaquil',
#  'Guillermo Rawson',
#  'Guillermo Roldan',
#  'Guizzo',
#  'Gustavo Cerati',
#  'Haití',
#  'Heroes de Malvinas',
#  'Hipólito Yrigoyen',
#  'Honduras',
#  'Humahuaca',
#  'Héroes Ara San Juan',
#  'Iberá',
#  'Iguazú',
#  'Incahuasi',
#  'Incas',
#  'Independencia',
#  'Indios Patagones',
#  'Intendente Arines',
#  'Intendente Carlos Pizzorno',
#  'Intendente Correa',
#  'Intendente Díaz',
#  'Intendente E. Seydell',
#  'Intendente Horacio Luis Cabezas',
#  'Intendente José F. Perazolo',
#  'Intendente Maciel',
#  'Intendente Miguel Ángel Veglia',
#  'Intendente Peña',
#  'Intendente Poretti',
#  'Intendente Reyno',
#  'Intendente Urtubey',
#  'Intendente de la Colina',
#  'Isidro Fernández Núñez',
#  'Italia',
#  'Ituzaingó',
#  'Ivan "Nene" Miranda',
#  'Jarilla',
#  'Joaquín Víctor González',
#  'Jorge Amadeo Lencina “Héroe de Guerra”',
#  'Jorge Cafrune',
#  'Jorge Falcón',
#  'Jorge Luis Borges',
#  'Jorge Newbery',
#  'Jorge Omar Aisama "Héroe de Guerra"',
#  'José A. Iglesias',
#  'José Ignacio Rucci',
#  'José Ingenieros',
#  'José Marti',
#  'José Pedernera',
#  'José Riesco',
#  'Juan A. Espindola',
#  'Juan C. Mulinetti',
#  'Juan José Castelli',
#  'Juan José Hernandez Arregui',
#  'Juan Muller',
#  'Juana Azurduy',
#  'Juana Moro',
#  'Jujuy',
#  'Julio Cortázar',
#  'Julio Sosa',
#  'Junin',
#  'Juramento',
#  'Juárez Celman',
#  'Juárez Célman',
#  'La Arbolada 10',
#  'La Arbolada 11',
#  'La Arbolada 12',
#  'La Arbolada 14',
#  'La Arbolada 15',
#  'La Arbolada 4',
#  'La Arbolada 5',
#  'La Arbolada 6',
#  'La Arbolada 7',
#  'La Arbolada 8',
#  'La Arbolada 9',
#  'La Pampa',
#  'La Plata',
#  'La Quiaca',
#  'La Rioja',
#  'Lacar',
#  'Lago Argentino',
#  'Laguna Blanca',
#  'Lamadrid',
#  'Lanin',
#  'Las Bahamas',
#  'Las Heras',
#  'Las Magnolias',
#  'Las Palmas',
#  'Las Violetas',
#  'Laura Broggi de Maciel',
#  'Leonardo Favio',
#  'Leopoldo Lugones',
#  'Libertad',
#  'Liniers',
#  'Lino Eneas Spilimbergo',
#  'Lisandro de la Torre',
#  'Lisignoli',
#  'Logistica del Centro',
#  'Lolog',
#  'Los Abedules',
#  'Los Aromos',
#  'Los Ceibales',
#  'Los Cipreses',
#  'Los Fresnos',
#  'Los Glaciares',
#  'Los Lapachos',
#  'Los Ombúes',
#  'Los Paraisos',
#  'Los Pinares',
#  'Los Robles',
#  'Los Rosales',
#  'Los Sauces',
#  'Los Talas',
#  'Luis Audelino Juárez',
#  'Luis Federico Leloir',
#  'Luis Sandrini',
#  'Lule',
#  'López y Planes',
#  'Macacha Guemes',
#  'Madrid',
#  'Maestro Nicolás Ormeño',
#  'Maestros Argentinos',
#  'Mafalda C. Gilli',
#  'Magallanes',
#  'Maipo',
#  'Maipú',
#  'Malvinas Argentinas',
#  'Manuel Abuelo',
#  'Manuel Belgrano',
#  'Manuel Dorrego',
#  'Manuel Moreno',
#  'Manuel Ocampo',
#  'Mar del Plata',
#  'Maracaibo',
#  'Marcelino Cuello',
#  'Marcelo Alberto Duzevich - Héroe de Malvinas',
#  'Marcelo Javier Suppo',
#  'Marcelo Pierantonelli',
#  'Marcelo T. de Alvear',
#  'Marcos Juárez',
#  'Mariano Ceballos',
#  'Mariano Moreno',
#  'Marie Curie',
#  'Marina Luchini',
#  'Mariquita Sánchez de Thompson',
#  'Martín Fierro',
#  'Martínez Mendoza',
#  'Mary Amaya',
#  'Massetti',
#  'Matheu',
#  'Medellín',
#  'Mendoza',
#  'Mercedarios',
#  'Mercedes Sosa',
#  'Miguel Abuelo',
#  'Miguel Moreno',
#  'Miramar',
#  'Mirotti',
#  'Misiones',
#  'Mocoví',
#  'Molle',
#  'Monte Hermoso',
#  'Monteagudo',
#  'Monterrey',
#  'Moradillo',
#  'Muller',
#  'México',
#  'Nahuel Huapi',
#  'Necochea',
#  'Neuquén',
#  'Newton',
#  'Nicolás Sarno',
#  'Nueva Esperanza',
#  'Oil! Combustibles',
#  'Olegario Andrade',
#  'Omar Ramonda',
#  'Ombú',
#  'Ona',
#  'Orcadas Argentinas',
#  'Orlando Bassi',
#  'Oscar Vicente "Cacho" Palermo',
#  'Pablo Colabianchi',
#  'Panamá',
#  'Paraguay',
#  'Parajón Ortiz',
#  'Paraná',
#  'Pasaje Cabo Adrián Bustos',
#  'Pasaje Chazarreta',
#  'Pasaje Falucho',
#  'Pasaje Formosa',
#  'Pasaje Irineo Victori',
#  'Pasaje Ituzaingó',
#  'Pasaje J. M. Iturral',
#  'Pasaje José Hernández',
#  'Pasaje Lautaro',
#  'Pasaje Monti',
#  'Pasaje P. y Arregui',
#  'Pasaje Peatonal Don Pablo Barrelier',
#  'Pasaje Privado',
#  'Pasaje Privado A',
#  'Pasaje Privado B',
#  'Pasaje Ramón Campagna',
#  'Pasaje República',
#  'Pasaje Riera',
#  'Pasaje San Roque',
#  'Pasaje Yapeyú',
#  'Paseo Concejal Héctor Ángel Massel',
#  'Paseo Juan Pablo II',
#  'Paseo Vilma Perrachione',
#  'Paseo de la Villa',
#  'Pasionaria',
#  'Paso de Ferreyra',
#  'Paso de la Patria',
#  'Paso de los Andes',
#  'Paso de los Libres',
#  'Pasteur',
#  'Pastor Cesar Hector Oviedo',
#  'Patagones',
#  'Paul Groussac',
#  'Paysandú',
#  'País Vasco',
#  'Peatonal San Martín',
#  'Pereyra',
#  'Periodistas Argentinos',
#  'Perito Moreno',
#  'Perú',
#  'Piedras',
#  'Pilagás',
#  'Pilcomayo',
#  'Piscis',
#  'Porfirio Seppey',
#  'Presidente Doctor Arturo Illia',
#  'Primera Junta',
#  'Pringles',
#  'Pro. Corrientes',
#  'Pro. Entre Ríos',
#  'Pro. Mendoza',
#  'Pro. Tucumán',
#  'Prof. Miguel "Chiche" Bravo',
#  'Profesora Adelina Barela de Martilotti',
#  'Profesora Lelia Repetto de Foguet',
#  'Profesora Norma Ninina Tais',
#  'Progreso',
#  'Providencia',
#  'Provincias Unidas',
#  'Puelches',
#  'Puelo',
#  'Puente Brigadier Juan Bautista Bustos',
#  'Puente Juan B. Alberdi',
#  'Puente Juan Domingo Perón',
#  'Puente caído',
#  'Puerto Argentina',
#  'Puerto Mont',
#  'Puerto Rico',
#  'Pueyrredón',
#  'Querandí',
#  'Quillén',
#  'Quinquela Martín',
#  'Quintana',
#  'Quito',
#  'Ramiro Suarez',
#  'Ramos Mejía',
#  'Ramón Campagna',
#  'Rankulche',
#  'Ranqueles',
#  'Rebeca Gerschman',
#  'Recife',
#  'Reconquista',
#  'Remedios de Escalada',
#  'República de Cuba',
#  'República de Israel',
#  'República de Siria',
#  'República del Líbano',
#  'Requena',
#  'Ricardo José Neri',
#  'Richard Erdwin Santoni',
#  'Rio Cuarto',
#  'Rio Parana',
#  'Rivadavia',
#  'Rivera Indarte',
#  'Rochi',
#  'Rodolfo Walsh',
#  'Roma',
#  'Romano Ferrari',
#  'Román Deheza',
#  'Rondeau',
#  'Rosario Vera Peñaloza',
#  'Rosita Corbari',
#  'Ruta 3 General José Gervasio Artigas',
#  'Ruta Nacional 158',
#  'Ruta Nacional 1V09',
#  'Ruta Provincial 2',
#  'Río Carcarañá',
#  'Río Chubut',
#  'Río Colorado',
#  'Río Desaguadero',
#  'Río Deseado',
#  'Río Dulce',
#  'Río Limay',
#  'Río Mendoza',
#  'Río Negro',
#  'Río Salado',
#  'Río Salí',
#  'Río Segundo',
#  'Río Suquía',
#  'Río Tercero',
#  'Río Tunuyán',
#  'Río Uruguay',
#  'Saavedra',
#  'Sabiá',
#  'Saint Exupery',
#  'Sal de Indio',
#  'Salomón Deiver',
#  'Salomón Gornitz',
#  'Salta',
#  'Salto Grande',
#  'San Juan',
#  'San Lorenzo',
#  'San Luis',
#  'San Martín',
#  'Sanavirón',
#  'Sandro (Roberto Sánchez)',
#  'Santa Cruz',
#  'Santa Fe',
#  'Santa Lucía',
#  'Santa Marta',
#  'Santiago Balerdi',
#  'Santiago del Estero',
#  'Sara Rietti',
#  'Sargento Cabral',
#  'Sargento Primero José L. Morano',
#  'Sarratea',
#  'Silvia del V. García',
#  'Soldados Argentinos',
#  'Soler',
#  'Solís',
#  'Sucre',
#  'Suiza',
#  'Sáenz Peña',
#  'Tacuarí',
#  'Tala',
#  'Tehuelches',
#  'Teniente Ibáñez',
#  'Tierra del Fuego',
#  'Timbó',
#  'Tobas',
#  'Tomás Edison',
#  'Traful',
#  'Transito Pesado',
#  'Tromen',
#  'Tronador',
#  'Tucumán',
#  'Tunel Ferroviario Hermanos Seco',
#  'Tupungato',
#  'Uritorco',
#  'Uruguay',
#  'Ushuaia',
#  'Uspallata',
#  'Valparaiso',
#  'Venezuela',
#  'Veracruz',
#  'Viamonte',
#  'Victoria Ocampo',
#  'Victoria Romero de Peñaloza',
#  'Victorino de la Plaza',
#  'Viedma',
#  'Viena',
#  'Viña del Mar',
#  'Víctor Mercante',
#  'Walt Disney',
#  'Yaragundi',
#  'Zorzal',
#  'calle pública',
#  'chaco',
#  'circunvalación proyectada',
#  'combate San Carlos',
#  'darsena de camiones en construcción',
#  'darsena de camiones en cosntrucción',
#  'Ángel Benito Cámpora',
#  'Ástor Piazzolla']

# %%
api = overpy.Overpass()
query = """
area["boundary"="administrative"]["name"="Villa Nueva"]["admin_level"="8"]->.searchArea;
way["highway"]["name"](area.searchArea);
out;
"""
result = api.query(query)

# extraer nombres únicos
calles = sorted({ way.tags["name"] for way in result.ways if "name" in way.tags })
calles
# Out:
# ['10 de Junio',
#  '12 de Octubre',
#  '2 de Abril',
#  '2 de Setiembre',
#  '25 de Mayo',
#  '26 de Septiembre',
#  '31 de Octubre',
#  '4 de Septiembre',
#  '5 de Julio',
#  '8 de Octubre',
#  '9 de Julio',
#  'A. Moreno',
#  'Alberdi',
#  'Alfredo Palacios',
#  'Alheli',
#  'Alicia Moreau de Justo',
#  'Almirante Brown',
#  'Alvear',
#  'Ambrosio Olmos',
#  'Antártida Argentina',
#  'Atacama',
#  'Atahualpa Yupanqui',
#  'Avellaneda',
#  'Avenida Arturo Humberto Illia',
#  'Avenida C. Atlántica',
#  'Avenida Carranza',
#  'Avenida Cervantes',
#  'Avenida Costanera',
#  'Avenida Gardenias',
#  'Avenida Henry Néstle',
#  'Avenida Juan Domingo Peron',
#  'Avenida La Pichona',
#  'Avenida Las Fresias',
#  'Avenida Las Violetas',
#  'Avenida Los Arrayanes',
#  'Avenida Los Ceibos',
#  'Avenida Los Gigantes',
#  'Avenida Los Lirios',
#  'Avenida Patria',
#  'Avenida Tilcara',
#  'Azucenas',
#  'Barberis',
#  'Bartolomé Mitre',
#  'Belgrano',
#  'Bolivar',
#  'Bosque Monte Blanco',
#  'Bosque de Araucarias',
#  'Bosque de Caldén',
#  'Bosque de Hayas',
#  'Bosque de Pataia',
#  'Bosque de Pehuen',
#  'Boulevard Dante Alighieri',
#  'Buenos Aires',
#  'Bulevar Argentino',
#  'Bulevar Don Antonio',
#  'Bulevar La Pichona',
#  'C.F. Tulian',
#  'Calchaqui',
#  'Caranday',
#  'Cariló',
#  'Carlos Pelegrini',
#  'Catamarca',
#  'Cda P. Bufarini',
#  'Cerro Aconcagua',
#  'Cerro Catedral',
#  'Cerro Champaquí',
#  'Cerro Lanin',
#  'Cerro Monte Olivia',
#  'Cerro Tronador',
#  'Chacabuco',
#  'Chaco',
#  'Chapadmalal',
#  'Chubut',
#  'Claromecó',
#  'Colón',
#  'Comercio',
#  'Corrientes',
#  'Cortada 7 de Octubre',
#  'Cortada Caritas',
#  'Cortada Evaristo Arias',
#  'Cortada Fernando Freyte',
#  'Cortada Pablo Granado',
#  'Cortada Paso de Ferreyra',
#  'Córdoba',
#  'Derqui',
#  'Deán Funes',
#  'Eduardo Daniele',
#  'El Aguaribay',
#  'El Escultor',
#  'El Jacaranda',
#  'El Mercantil',
#  'Elvio Spinelli',
#  'Entre Ríos',
#  'España',
#  'Esteban Echeverria',
#  'Eva Perón',
#  'Figueroa Alcorta',
#  'Flor de Iris',
#  'Florida',
#  'Formosa',
#  'Francia',
#  'García Lorca',
#  'General Paz',
#  'Gerbera',
#  'González Camadero',
#  'Hilario Ascasubi',
#  'Hipólito Yrigoyen',
#  'Hornillos',
#  'Humahuaca',
#  'Independencia',
#  'Intendente Paviotti',
#  'Isabel la Católica',
#  'Isidro Fernández Núñez',
#  'Italia',
#  'Ituzaingó',
#  'Ivira',
#  'José Hernández',
#  'José Ingenieros',
#  'José Luis Cabezas',
#  'José Luis Sarasa',
#  'Juana Manso',
#  'Juarez Celman',
#  'Jujuy',
#  'Justo José de Urquiza',
#  'La Alameda',
#  'La Pampa',
#  'La Quiaca',
#  'La Rioja',
#  'Lago Aluminé',
#  'Lago Blanco',
#  'Lago Cardiel',
#  'Lago Correntoso',
#  'Lago Epuyen',
#  'Lago Escondido',
#  'Lago Fagnano',
#  'Lago Fontana',
#  'Lago Gutiérrez',
#  'Lago Hermoso',
#  'Lago Lacar',
#  'Lago Martin',
#  'Lago Mascardi',
#  'Lago Muster',
#  'Lago Nahuel Huapi',
#  'Lago Puelo',
#  'Lago Quillen',
#  'Lago Traful',
#  'Laprida',
#  'Las Acacias',
#  'Las Amapolas',
#  'Las Azaleas',
#  'Las Azucenas',
#  'Las Calandrias',
#  'Las Camelias',
#  'Las Dalias',
#  'Las Gaviotas',
#  'Las Hortensias',
#  'Las Orquídeas',
#  'Las Palmeras',
#  'Las Toninas',
#  'Lavanda',
#  'Leandro N. Alem',
#  'Libertad',
#  'Lima',
#  'Lisandro de la Torre',
#  'Los Abedules',
#  'Los Alerces',
#  'Los Algarrobos',
#  'Los Aromitos',
#  'Los Caldenes',
#  'Los Canarios',
#  'Los Chañares',
#  'Los Cocos',
#  'Los Colibries',
#  'Los Espinillos',
#  'Los Eucaliptos',
#  'Los Flamencos',
#  'Los Fresnos',
#  'Los Gladiolos',
#  'Los Jacintos',
#  'Los Jazmines',
#  'Los Jigleros',
#  'Los Lapachos',
#  'Los Nogales',
#  'Los Olivares',
#  'Los Paraisos',
#  'Los Pinos',
#  'Los Plátanos',
#  'Los Quebrachos',
#  'Los Robles',
#  'Los Talas',
#  'Los Tilos',
#  'Los Tulipanes',
#  'Los Zorzales',
#  'Luciana Vaudagnotto',
#  'Lucio Mansilla',
#  'Luis Vernet',
#  'López y Planes',
#  'Maimara',
#  'Maipú',
#  'Malvinas Argentinas',
#  'Manuel Mujica Láinez',
#  'Manuel de Falla',
#  'Mar Chiquita',
#  'Mar de Ajó',
#  'Mar de las Pampas',
#  'Mar del Plata',
#  'Marcos Juárez',
#  'Mendoza',
#  'Miramar',
#  'Misiones',
#  'Modesto Moreno',
#  'Monte Hermoso',
#  'Monte Piscis',
#  'Moradillo',
#  'Namumcurá',
#  'Necochea',
#  'Neuquén',
#  'Padre Hugo Salvato',
#  'Paraguay',
#  'Pasaje Charrua',
#  'Pasaje Tehuelche',
#  'Pasionaria',
#  'Paula Albarracín',
#  'Pedro de Mendoza',
#  'Piedras',
#  'Pinamar',
#  'Presidente Perón',
#  'Primero de Mayo',
#  'Pueblos Originarios',
#  'Puente Brigadier Juan Bautista Bustos',
#  'Puente Juan B. Alberdi',
#  'Puente Juan Domingo Perón',
#  'Puerto Argentino',
#  'Punta Mogotes',
#  'Purmamarca',
#  'Querandi',
#  'Ramón José Cárcano',
#  'Raúl Ricardo Alfonsín',
#  'Regina Pie de Casas',
#  'Ricardo Balbín',
#  'Rio Negro',
#  'Rivadavia',
#  'Rivero',
#  'Roldán',
#  'Ruta Provincial 2',
#  'Ruta Provincial 4',
#  'Saavedra',
#  'Salta',
#  'San Bernardo',
#  'San Cayetano',
#  'San Clemente del Tuyú',
#  'San Juan',
#  'San Lorenzo',
#  'San Luis',
#  'San Martín',
#  'San Roque',
#  'Santa Clara del Mar',
#  'Santa Cruz',
#  'Santa Fe',
#  'Santa Teresita',
#  'Santiago del Estero',
#  'Sarmiento',
#  'Siempreviva',
#  'Soldado Carlos Daniel Ferreyra',
#  'Soldado Daniel Leon Reina',
#  'Sombra de Toro',
#  'Sáenz Peña',
#  'Tabaquillo',
#  'Tala',
#  'Toba',
#  'Tucumán',
#  'Varas Alonso',
#  'Velez Sarsfield',
#  'Verbenas',
#  'Victoria Ocampo',
#  'Villa Gesell',
#  'Villamonte',
#  'Ñandubay']
